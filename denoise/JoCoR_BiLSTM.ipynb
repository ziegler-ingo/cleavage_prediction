# %%
# JoCoR
# https://arxiv.org/abs/2003.02752

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
import os
import sys
import csv
import pickle
import random
import math
import numpy as np
from time import time
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.parametrizations import spectral_norm

from torchtext.vocab import build_vocab_from_iterator

from sklearn.metrics import roc_auc_score

# %%
def seed_everything(seed: int):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
seed_everything(1234)

# %%
def read_data(path):
    with open(path, 'r') as csvfile:
        train_data = list(csv.reader(csvfile))[1:] # skip col name
        sents, lbls = [], []
        for s, l in train_data:
            sents.append(s)
            lbls.append(l)
    return sents, lbls

# number of trainable parameters in model
def get_total_model_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def gelu(x):
    """
    Facebook Research implementation of the gelu activation function.
    
    For information: OpenAI GPT's gelu is slightly different
    (and gives slightly different results):
    0.5 * x * (1 + torch.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * torch.pow(x, 3))))
    """
    return x * 0.5 * (1.0 + torch.erf(x / math.sqrt(2.0)))

# %%
class CleavageDataset(Dataset):
    def __init__(self, seq, lbl):
        self.seq = seq
        self.lbl = lbl
    
    def __getitem__(self, idx):
        return self.seq[idx], self.lbl[idx]
    
    def __len__(self):
        return len(self.lbl)
    
class CleavageBatch:
    def __init__(self, batch):
        ordered_batch = list(zip(*batch))
        self.seq = torch.tensor([encode_text(seq) for seq in ordered_batch[0]], dtype=torch.int64)
        self.lbl = torch.tensor([int(l) for l in ordered_batch[1]], dtype=torch.float)
        
    def pin_memory(self):
        self.seq = self.seq.pin_memory()
        self.lbl = self.lbl.pin_memory()
        return self
    
def collate_wrapper(batch):
    return CleavageBatch(batch)

# %%
class BiLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, rnn_size1, rnn_size2, hidden_size, dropout):
        super().__init__()
        
        self.embedding = nn.Embedding(
            num_embeddings=vocab_size,
            embedding_dim=embedding_dim,
        )
        
        self.dropout=nn.Dropout(dropout)
        
        self.lstm1 = nn.LSTM(
            input_size=embedding_dim,
            hidden_size=rnn_size1,
            bidirectional=True,
            batch_first=True,
        )

        self.lstm2 = nn.LSTM(
            input_size=2 * rnn_size1,
            hidden_size=rnn_size2,
            bidirectional=True,
            batch_first=True,
        )
        
        self.fc1 = spectral_norm(nn.Linear(rnn_size2 * 2, hidden_size))
        self.fc2 = nn.Linear(hidden_size, 1)
        
    def forward(self, seq):
        # input shape: (batch_size, seq_len=10)
        embedded = self.dropout(self.embedding(seq))
        
        # input shape: (batch_size, seq_len, embedding_dim)
        out, _ = self.lstm1(embedded)
        
        # input shape: (batch_size, seq_len, 2*rnn_size1)
        out, _ = self.lstm2(out)
        
        # input shape: (batch_size, seq_len, 2*hidden_size)
        pooled, _ = torch.max(out, dim=1)
        
        # input shape: (batch_size, 2*hidden_size)
        out = self.dropout(gelu(self.fc1(pooled)))
        
        # input shape: (batch_size, hidden_size)
        # output shape: (batch_size)
        return self.fc2(out).squeeze()

# %%
# Loss functions

# JoCoR
# https://github.com/chengtan9907/Co-learning-Learning-from-noisy-labels-with-self-supervision/blob/master/losses/loss_jocor.py


import scipy
import torch 
import torch.nn as nn
import numpy as np
import math
import torch.nn.functional as F
from scipy import special

eps = 1e-12

def kl_loss_compute(pred, soft_targets, reduction="none"):
    kl = F.kl_div(
        F.logsigmoid(pred),
        #F.sigmoid(soft_targets),
        torch.sigmoid(soft_targets),
        reduction="none")

    if reduction=="none":
        return torch.mean(torch.sum(kl))
    else:
        return torch.sum(kl)

def Distance_squared(x, y, featdim=1):
    m, n = x.size(0), y.size(0)
    xx = torch.pow(x, 2).sum(1, keepdim=True).expand(m, n)
    yy = torch.pow(y, 2).sum(1, keepdim=True).expand(n, m).t()
    dist = xx + yy
    dist.addmm_(x, y.t(), beta=1, alpha=-2)
    d = dist.clamp(min=eps)
    d[torch.eye(d.shape[0]) == 1] = eps
    return d

def CalPairwise(dist):
    dist[dist < 0] = 0
    Pij = torch.exp(-dist)
    return Pij

def CalPairwise_t(dist, v):
    C = scipy.special.gamma((v + 1) / 2) / (np.sqrt(v * np.pi) * scipy.special.gamma(v / 2))
    return torch.pow((1 + torch.pow(dist, 2) / v), - (v + 1) / 2)

def CE(P, Q):
    loss = -1 * (P * torch.log(Q + eps)).mean()
    return loss
  
def loss_jocor(y1, y2, labels, forget_rate, co_lambda=0.1):

    criterion = nn.BCEWithLogitsLoss(reduction="none")

    loss_pick_1 = criterion(y1, labels) * (1 - co_lambda)
    loss_pick_2 = criterion(y2, labels) * (1 - co_lambda)
    loss_pick = (loss_pick_1 + loss_pick_2 + co_lambda * kl_loss_compute(y1, y2,reduction="none") + co_lambda * kl_loss_compute(y2, y1, reduction="none")).cpu()

    ind_sorted = np.argsort(loss_pick.data)
    loss_sorted = loss_pick[ind_sorted]

    remember_rate = 1 - forget_rate
    num_remember = int(remember_rate * len(loss_sorted))

    ind_update = ind_sorted[:num_remember]

    loss = torch.mean(loss_pick[ind_update])

    return loss, loss

# %%
def process(model1, model2, loader, forget_rate, optim=None):
    epoch_loss1, num_correct1, total = 0, 0, 0
    epoch_loss2, num_correct2 = 0, 0

    preds1, preds2, lbls = [], [], []
    
    for batch in tqdm(
        loader,
        desc="Train: " if optim is not None else "Eval: ",
        file=sys.stdout,
        unit="batches"
    ):
        seq, lbl = batch.seq, batch.lbl
        seq, lbl = seq.to(device), lbl.to(device)
        
        scores1 = model1(seq)
        scores2 = model1(seq)

        loss1, loss2= loss_jocor(scores1, scores2, lbl, forget_rate)
        
        if optim is not None:
            optim.zero_grad()
            loss1.backward()
            optim.step()
        
        epoch_loss1 += loss1.item()
        epoch_loss2 += loss2.item()
        num_correct1 += ((scores1 > 0) == lbl).sum()
        num_correct2 += ((scores2 > 0) == lbl).sum()
        total += len(seq)
        preds1.extend(scores1.detach().tolist())
        preds2.extend(scores2.detach().tolist())
        lbls.extend(lbl.detach().tolist())
    return epoch_loss1 / total, epoch_loss2 / total, num_correct1 / total, num_correct2 / total, roc_auc_score(lbls, preds1), roc_auc_score(lbls, preds2)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# load train and dev data
train_seqs, train_lbl = read_data('data/n_train.csv')
dev_seqs, dev_lbl = read_data('data/n_val.csv')

# create vocab from train seqs
vocab = build_vocab_from_iterator(train_seqs, specials=['<UNK>'])
vocab.set_default_index(vocab['<UNK>'])
encode_text = lambda x: vocab(list(x))

# %%
NUM_EPOCHS = 25
BATCH_SIZE = 512
VOCAB_SIZE = len(vocab)
EMBEDDING_DIM = 200
RNN_SIZE1 = 256
RNN_SIZE2 = 512
HIDDEN_SIZE = 128
DROPOUT = 0.5
LEARNING_RATE = 5e-5

NUM_GRADUAL = 10 # how many epochs for linear drop rate, can be 5, 10, 15. This parameter is equal to Tk for R(T) in Co-teaching paper.
NOISY_RATE = 0.2
FORGET_RATE = 0.2
EXPONENT = 1

# define drop rate schedule
rate_schedule = np.ones(NUM_EPOCHS)*FORGET_RATE
rate_schedule[:NUM_GRADUAL] = np.linspace(0, FORGET_RATE**EXPONENT, NUM_GRADUAL)


model1 = BiLSTM(
    vocab_size=VOCAB_SIZE,
    embedding_dim=EMBEDDING_DIM,
    rnn_size1=RNN_SIZE1,
    rnn_size2=RNN_SIZE2,
    hidden_size=HIDDEN_SIZE,
    dropout=DROPOUT
).to(device)

model2 = BiLSTM(
    vocab_size=VOCAB_SIZE,
    embedding_dim=EMBEDDING_DIM,
    rnn_size1=RNN_SIZE1,
    rnn_size2=RNN_SIZE2,
    hidden_size=HIDDEN_SIZE,
    dropout=DROPOUT
).to(device)

optimizer = optim.Adam(model1.parameters(), lr=LEARNING_RATE)
criterion = nn.BCEWithLogitsLoss(reduction="none")

# create train and dev loader
train_data = CleavageDataset(train_seqs, train_lbl)
train_loader = DataLoader(train_data, batch_size = BATCH_SIZE, shuffle=True, collate_fn=collate_wrapper, pin_memory=True, num_workers=2)

dev_data = CleavageDataset(dev_seqs, dev_lbl)
dev_loader = DataLoader(dev_data, batch_size = BATCH_SIZE, shuffle=True, collate_fn=collate_wrapper, pin_memory=True, num_workers=2)

print(f"Total trainable model1 parameters: {get_total_model_params(model1):,}")
print(f"Total trainable model2 parameters: {get_total_model_params(model1):,}")
# Out:
# Total trainable model1 parameters: 5,276,009
# Total trainable model2 parameters: 5,276,009

# %%
start = time()
print("Starting Training.")

highest_val_auc1, highest_val_auc2 = 0,0
train_losses1, train_accuracies1, train_aucs1= [], [], []
train_losses2, train_accuracies2, train_aucs2= [], [], []
val_losses1, val_accuracies1, val_aucs1 = [], [], []
val_losses2, val_accuracies2, val_aucs2 = [], [], []

for epoch in range(1, NUM_EPOCHS + 1):
    model1.train()
    model2.train()
    train_loss1, train_loss2, train_acc1, train_acc2, train_auc1, train_auc2 = process(model1, model2, train_loader, rate_schedule[epoch-1], optimizer)
    
    model1.eval()
    model2.eval()
    with torch.no_grad():
        val_loss1, val_loss2, val_acc1, val_acc2, val_auc1, val_auc2 = process(model1, model2, dev_loader, rate_schedule[epoch-1])
        
    # save current acc, loss model1
    train_losses1.append((epoch, train_loss1))
    train_accuracies1.append((epoch, train_acc1))
    train_aucs1.append((epoch, train_auc1))
    val_losses1.append((epoch, val_loss1))
    val_accuracies1.append((epoch, val_acc1))
    val_aucs1.append((epoch, val_auc1))
    
    if val_auc1 > highest_val_auc1:
        highest_val_auc1 = val_auc1
        path = f"params/jocor/model1_auc{val_auc1:.4f}_epoch{epoch}.pt"
        torch.save(model1.state_dict(), path)
        
    print(f"Model 1 Training:   [Epoch {epoch:2d}, Loss: {train_loss1:8.4f}, Acc: {train_acc1:.4f}, AUC: {train_auc1:.4f}]")
    print(f"Model 1 Evaluation: [Epoch {epoch:2d}, Loss: {val_loss1:8.4f}, Acc: {val_acc1:.4f}, AUC: {val_auc1:.4f}]")

    # save current acc, loss model2
    train_losses2.append((epoch, train_loss2))
    train_accuracies2.append((epoch, train_acc2))
    train_aucs2.append((epoch, train_auc2))
    val_losses2.append((epoch, val_loss2))
    val_accuracies2.append((epoch, val_acc2))
    val_aucs2.append((epoch, val_auc2))
    
    if val_auc2 > highest_val_auc2:
        highest_val_auc2 = val_auc2
        path = f"params/jocor/model2_auc{val_auc2:.4f}_epoch{epoch}.pt"
        torch.save(model2.state_dict(), path)
        
    print(f"Model 2 Training:   [Epoch {epoch:2d}, Loss: {train_loss2:8.4f}, Acc: {train_acc2:.4f}, AUC: {train_auc2:.4f}]")
    print(f"Model 2 Evaluation: [Epoch {epoch:2d}, Loss: {val_loss2:8.4f}, Acc: {val_acc2:.4f}, AUC: {val_auc2:.4f}]")

    
print("Finished Training.")
train_time = (time() - start) / 60
print(f"Training took {train_time} minutes.")
# Out:
# Starting Training.
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.64batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.83batches/s]
# Model 1 Training:   [Epoch  1, Loss:   0.0024, Acc: 0.6071, AUC: 0.6444]
# Model 1 Evaluation: [Epoch  1, Loss:   0.0021, Acc: 0.6818, AUC: 0.7469]
# Model 2 Training:   [Epoch  1, Loss:   0.0024, Acc: 0.6070, AUC: 0.6444]
# Model 2 Evaluation: [Epoch  1, Loss:   0.0021, Acc: 0.6818, AUC: 0.7469]
# Train: 100%|██████████| 2236/2236 [03:49<00:00,  9.74batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.95batches/s]
# Model 1 Training:   [Epoch  2, Loss:   0.0021, Acc: 0.6839, AUC: 0.7486]
# Model 1 Evaluation: [Epoch  2, Loss:   0.0019, Acc: 0.6875, AUC: 0.7558]
# Model 2 Training:   [Epoch  2, Loss:   0.0021, Acc: 0.6838, AUC: 0.7487]
# Model 2 Evaluation: [Epoch  2, Loss:   0.0019, Acc: 0.6875, AUC: 0.7558]
# Train: 100%|██████████| 2236/2236 [03:49<00:00,  9.76batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.93batches/s]
# Model 1 Training:   [Epoch  3, Loss:   0.0019, Acc: 0.6872, AUC: 0.7484]
# Model 1 Evaluation: [Epoch  3, Loss:   0.0017, Acc: 0.6895, AUC: 0.7556]
# Model 2 Training:   [Epoch  3, Loss:   0.0019, Acc: 0.6873, AUC: 0.7483]
# Model 2 Evaluation: [Epoch  3, Loss:   0.0017, Acc: 0.6895, AUC: 0.7556]
# Train: 100%|██████████| 2236/2236 [03:49<00:00,  9.73batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.97batches/s]
# Model 1 Training:   [Epoch  4, Loss:   0.0016, Acc: 0.6888, AUC: 0.7492]
# Model 1 Evaluation: [Epoch  4, Loss:   0.0016, Acc: 0.6912, AUC: 0.7570]
# Model 2 Training:   [Epoch  4, Loss:   0.0016, Acc: 0.6888, AUC: 0.7491]
# Model 2 Evaluation: [Epoch  4, Loss:   0.0016, Acc: 0.6912, AUC: 0.7570]
# Train: 100%|██████████| 2236/2236 [03:50<00:00,  9.69batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.79batches/s]
# Model 1 Training:   [Epoch  5, Loss:   0.0015, Acc: 0.6896, AUC: 0.7501]
# Model 1 Evaluation: [Epoch  5, Loss:   0.0014, Acc: 0.6928, AUC: 0.7574]
# Model 2 Training:   [Epoch  5, Loss:   0.0015, Acc: 0.6896, AUC: 0.7501]
# Model 2 Evaluation: [Epoch  5, Loss:   0.0014, Acc: 0.6928, AUC: 0.7574]
# Train: 100%|██████████| 2236/2236 [03:49<00:00,  9.73batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.03batches/s]
# Model 1 Training:   [Epoch  6, Loss:   0.0014, Acc: 0.6907, AUC: 0.7508]
# Model 1 Evaluation: [Epoch  6, Loss:   0.0013, Acc: 0.6920, AUC: 0.7575]
# Model 2 Training:   [Epoch  6, Loss:   0.0014, Acc: 0.6909, AUC: 0.7508]
# Model 2 Evaluation: [Epoch  6, Loss:   0.0013, Acc: 0.6920, AUC: 0.7575]
# Train: 100%|██████████| 2236/2236 [03:50<00:00,  9.71batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.91batches/s]
# Model 1 Training:   [Epoch  7, Loss:   0.0012, Acc: 0.6913, AUC: 0.7501]
# Model 1 Evaluation: [Epoch  7, Loss:   0.0012, Acc: 0.6898, AUC: 0.7582]
# Model 2 Training:   [Epoch  7, Loss:   0.0012, Acc: 0.6913, AUC: 0.7502]
# Model 2 Evaluation: [Epoch  7, Loss:   0.0012, Acc: 0.6898, AUC: 0.7582]
# Train: 100%|██████████| 2236/2236 [03:49<00:00,  9.72batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 30.05batches/s]
# Model 1 Training:   [Epoch  8, Loss:   0.0011, Acc: 0.6911, AUC: 0.7488]
# Model 1 Evaluation: [Epoch  8, Loss:   0.0011, Acc: 0.6878, AUC: 0.7559]
# Model 2 Training:   [Epoch  8, Loss:   0.0011, Acc: 0.6912, AUC: 0.7487]
# Model 2 Evaluation: [Epoch  8, Loss:   0.0011, Acc: 0.6878, AUC: 0.7559]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.67batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.93batches/s]
# Model 1 Training:   [Epoch  9, Loss:   0.0010, Acc: 0.6912, AUC: 0.7480]
# Model 1 Evaluation: [Epoch  9, Loss:   0.0009, Acc: 0.6917, AUC: 0.7563]
# Model 2 Training:   [Epoch  9, Loss:   0.0010, Acc: 0.6911, AUC: 0.7480]
# Model 2 Evaluation: [Epoch  9, Loss:   0.0009, Acc: 0.6917, AUC: 0.7563]
# Train: 100%|██████████| 2236/2236 [03:50<00:00,  9.71batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.45batches/s]
# Model 1 Training:   [Epoch 10, Loss:   0.0009, Acc: 0.6905, AUC: 0.7472]
# Model 1 Evaluation: [Epoch 10, Loss:   0.0008, Acc: 0.6904, AUC: 0.7547]
# Model 2 Training:   [Epoch 10, Loss:   0.0009, Acc: 0.6903, AUC: 0.7473]
# Model 2 Evaluation: [Epoch 10, Loss:   0.0008, Acc: 0.6904, AUC: 0.7547]
# Train: 100%|██████████| 2236/2236 [03:50<00:00,  9.70batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.98batches/s]
# Model 1 Training:   [Epoch 11, Loss:   0.0009, Acc: 0.6916, AUC: 0.7474]
# Model 1 Evaluation: [Epoch 11, Loss:   0.0008, Acc: 0.6916, AUC: 0.7563]
# Model 2 Training:   [Epoch 11, Loss:   0.0009, Acc: 0.6916, AUC: 0.7475]
# Model 2 Evaluation: [Epoch 11, Loss:   0.0008, Acc: 0.6916, AUC: 0.7563]
# Train: 100%|██████████| 2236/2236 [03:50<00:00,  9.69batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.96batches/s]
# Model 1 Training:   [Epoch 12, Loss:   0.0009, Acc: 0.6926, AUC: 0.7479]
# Model 1 Evaluation: [Epoch 12, Loss:   0.0008, Acc: 0.6922, AUC: 0.7566]
# Model 2 Training:   [Epoch 12, Loss:   0.0009, Acc: 0.6927, AUC: 0.7477]
# Model 2 Evaluation: [Epoch 12, Loss:   0.0008, Acc: 0.6922, AUC: 0.7566]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.67batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.88batches/s]
# Model 1 Training:   [Epoch 13, Loss:   0.0008, Acc: 0.6936, AUC: 0.7483]
# Model 1 Evaluation: [Epoch 13, Loss:   0.0008, Acc: 0.6921, AUC: 0.7575]
# Model 2 Training:   [Epoch 13, Loss:   0.0008, Acc: 0.6934, AUC: 0.7482]
# Model 2 Evaluation: [Epoch 13, Loss:   0.0008, Acc: 0.6921, AUC: 0.7575]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.67batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.97batches/s]
# Model 1 Training:   [Epoch 14, Loss:   0.0008, Acc: 0.6938, AUC: 0.7481]
# Model 1 Evaluation: [Epoch 14, Loss:   0.0008, Acc: 0.6928, AUC: 0.7570]
# Model 2 Training:   [Epoch 14, Loss:   0.0008, Acc: 0.6937, AUC: 0.7483]
# Model 2 Evaluation: [Epoch 14, Loss:   0.0008, Acc: 0.6928, AUC: 0.7570]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.65batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.79batches/s]
# Model 1 Training:   [Epoch 15, Loss:   0.0008, Acc: 0.6940, AUC: 0.7482]
# Model 1 Evaluation: [Epoch 15, Loss:   0.0008, Acc: 0.6934, AUC: 0.7578]
# Model 2 Training:   [Epoch 15, Loss:   0.0008, Acc: 0.6941, AUC: 0.7480]
# Model 2 Evaluation: [Epoch 15, Loss:   0.0008, Acc: 0.6934, AUC: 0.7578]
# Train: 100%|██████████| 2236/2236 [03:50<00:00,  9.68batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.89batches/s]
# Model 1 Training:   [Epoch 16, Loss:   0.0008, Acc: 0.6944, AUC: 0.7486]
# Model 1 Evaluation: [Epoch 16, Loss:   0.0008, Acc: 0.6925, AUC: 0.7577]
# Model 2 Training:   [Epoch 16, Loss:   0.0008, Acc: 0.6944, AUC: 0.7487]
# Model 2 Evaluation: [Epoch 16, Loss:   0.0008, Acc: 0.6925, AUC: 0.7577]
# Train: 100%|██████████| 2236/2236 [03:50<00:00,  9.69batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.98batches/s]
# Model 1 Training:   [Epoch 17, Loss:   0.0008, Acc: 0.6950, AUC: 0.7488]
# Model 1 Evaluation: [Epoch 17, Loss:   0.0008, Acc: 0.6922, AUC: 0.7584]
# Model 2 Training:   [Epoch 17, Loss:   0.0008, Acc: 0.6949, AUC: 0.7488]
# Model 2 Evaluation: [Epoch 17, Loss:   0.0008, Acc: 0.6922, AUC: 0.7584]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.67batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.86batches/s]
# Model 1 Training:   [Epoch 18, Loss:   0.0008, Acc: 0.6951, AUC: 0.7484]
# Model 1 Evaluation: [Epoch 18, Loss:   0.0008, Acc: 0.6917, AUC: 0.7591]
# Model 2 Training:   [Epoch 18, Loss:   0.0008, Acc: 0.6949, AUC: 0.7486]
# Model 2 Evaluation: [Epoch 18, Loss:   0.0008, Acc: 0.6917, AUC: 0.7591]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.66batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.81batches/s]
# Model 1 Training:   [Epoch 19, Loss:   0.0008, Acc: 0.6952, AUC: 0.7481]
# Model 1 Evaluation: [Epoch 19, Loss:   0.0008, Acc: 0.6945, AUC: 0.7595]
# Model 2 Training:   [Epoch 19, Loss:   0.0008, Acc: 0.6951, AUC: 0.7480]
# Model 2 Evaluation: [Epoch 19, Loss:   0.0008, Acc: 0.6945, AUC: 0.7595]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.67batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.74batches/s]
# Model 1 Training:   [Epoch 20, Loss:   0.0008, Acc: 0.6947, AUC: 0.7469]
# Model 1 Evaluation: [Epoch 20, Loss:   0.0008, Acc: 0.6932, AUC: 0.7569]
# Model 2 Training:   [Epoch 20, Loss:   0.0008, Acc: 0.6947, AUC: 0.7471]
# Model 2 Evaluation: [Epoch 20, Loss:   0.0008, Acc: 0.6932, AUC: 0.7569]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.66batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.07batches/s]
# Model 1 Training:   [Epoch 21, Loss:   0.0008, Acc: 0.6961, AUC: 0.7491]
# Model 1 Evaluation: [Epoch 21, Loss:   0.0007, Acc: 0.6943, AUC: 0.7591]
# Model 2 Training:   [Epoch 21, Loss:   0.0008, Acc: 0.6960, AUC: 0.7492]
# Model 2 Evaluation: [Epoch 21, Loss:   0.0007, Acc: 0.6943, AUC: 0.7591]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.68batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.99batches/s]
# Model 1 Training:   [Epoch 22, Loss:   0.0008, Acc: 0.6962, AUC: 0.7488]
# Model 1 Evaluation: [Epoch 22, Loss:   0.0008, Acc: 0.6943, AUC: 0.7584]
# Model 2 Training:   [Epoch 22, Loss:   0.0008, Acc: 0.6962, AUC: 0.7486]
# Model 2 Evaluation: [Epoch 22, Loss:   0.0008, Acc: 0.6943, AUC: 0.7584]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.68batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.80batches/s]
# Model 1 Training:   [Epoch 23, Loss:   0.0008, Acc: 0.6961, AUC: 0.7485]
# Model 1 Evaluation: [Epoch 23, Loss:   0.0007, Acc: 0.6941, AUC: 0.7592]
# Model 2 Training:   [Epoch 23, Loss:   0.0008, Acc: 0.6960, AUC: 0.7485]
# Model 2 Evaluation: [Epoch 23, Loss:   0.0007, Acc: 0.6941, AUC: 0.7592]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.66batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.96batches/s]
# Model 1 Training:   [Epoch 24, Loss:   0.0008, Acc: 0.6964, AUC: 0.7482]
# Model 1 Evaluation: [Epoch 24, Loss:   0.0008, Acc: 0.6933, AUC: 0.7588]
# Model 2 Training:   [Epoch 24, Loss:   0.0008, Acc: 0.6964, AUC: 0.7481]
# Model 2 Evaluation: [Epoch 24, Loss:   0.0008, Acc: 0.6933, AUC: 0.7588]
# Train: 100%|██████████| 2236/2236 [03:51<00:00,  9.67batches/s]
# Eval: 100%|██████████| 280/280 [00:09<00:00, 29.78batches/s]
# Model 1 Training:   [Epoch 25, Loss:   0.0008, Acc: 0.6965, AUC: 0.7478]
# Model 1 Evaluation: [Epoch 25, Loss:   0.0007, Acc: 0.6958, AUC: 0.7595]
# Model 2 Training:   [Epoch 25, Loss:   0.0008, Acc: 0.6967, AUC: 0.7477]
# Model 2 Evaluation: [Epoch 25, Loss:   0.0007, Acc: 0.6958, AUC: 0.7595]
# Finished Training.
# Training took 100.84271794954935 minutes.

# %%
# save training stats
lsts = [train_losses, train_accuracies, val_losses, val_accuracies, train_aucs, val_aucs, train_time]
names = [
    "train_losses",
    "train_accuracies",
    "val_losses",
    "val_accuracies",
    "train_aucs",
    "val_aucs",
    "train_time",
]
to_save = dict()
for name, lst in zip(names, lsts):
    to_save[name] = lst

with open(f"../../params/n_term/BiLSTM/metrics.pkl", "wb") as f:
    pickle.dump(to_save, f, pickle.HIGHEST_PROTOCOL)

print("Finished Saving Details.")
