# %%
import os
import csv
import math
import pickle
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from torchtext.vocab import build_vocab_from_iterator

from sklearn.metrics import roc_auc_score

from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler
from ray.tune import ExperimentAnalysis

# %%
def seed_everything(seed: int):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
seed_everything(1234)

# %%
def read_data(path):
    with open(path, 'r') as csvfile:
        train_data = list(csv.reader(csvfile))[1:] # skip col name
        sents, lbls = [], []
        for s, l in train_data:
            sents.append(s)
            lbls.append(l)
    return sents, lbls

def apply_random_masking(seq, num_tokens):
    """
    Mask `num_tokens` as 0 at random positions per sequence. 
    """
    dist = torch.rand(seq.shape)
    m, _ = torch.topk(dist, num_tokens)
    return seq * (dist < m)

def gelu(x):
    """
    Facebook Research implementation of the gelu activation function.
    
    For information: OpenAI GPT's gelu is slightly different
    (and gives slightly different results):
    0.5 * x * (1 + torch.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * torch.pow(x, 3))))
    """
    return x * 0.5 * (1.0 + torch.erf(x / math.sqrt(2.0)))

def regularized_auc(train_auc, dev_auc, threshold=0.0025):
    """
    Returns development AUC if overfitting is below threshold, otherwise 0.
    """
    return dev_auc if (train_auc - dev_auc) < threshold else 0

# %%
class CleavageDataset(Dataset):
    def __init__(self, seq, lbl):
        self.seq = seq
        self.lbl = lbl
    
    def __getitem__(self, idx):
        return self.seq[idx], self.lbl[idx]
    
    def __len__(self):
        return len(self.lbl)
    
def collate_train(batch):
    ordered_batch = list(zip(*batch))
    seq = torch.tensor([encode_text(seq) for seq in ordered_batch[0]], dtype=torch.int64)
    seq = apply_random_masking(seq, num_tokens=1)
    lbl = torch.tensor([int(l) for l in ordered_batch[1]], dtype=torch.float)
    return seq, lbl

def collate_dev(batch):
    ordered_batch = list(zip(*batch))
    seq = torch.tensor([encode_text(seq) for seq in ordered_batch[0]], dtype=torch.int64)
    lbl = torch.tensor([int(l) for l in ordered_batch[1]], dtype=torch.float)
    return seq, lbl

# %%
class BiLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, rnn_size1, rnn_size2, hidden_size, dropout):
        super().__init__()
        
        self.embedding = nn.Embedding(
            num_embeddings=vocab_size,
            embedding_dim=embedding_dim,
        )
        
        self.dropout=nn.Dropout(dropout)
        
        self.lstm1 = nn.LSTM(
            input_size=embedding_dim,
            hidden_size=rnn_size1,
            bidirectional=True,
            batch_first=True,
        )

        self.lstm2 = nn.LSTM(
            input_size=2 * rnn_size1,
            hidden_size=rnn_size2,
            bidirectional=True,
            batch_first=True,
        )
        
        self.fc1 = nn.Linear(rnn_size2 * 2, hidden_size)
        self.fc2 = nn.Linear(hidden_size, 1)
        
    def forward(self, seq):
        # input shape: (batch_size, seq_len=10)
        embedded = self.dropout(self.embedding(seq))
        
        # input shape: (batch_size, seq_len, embedding_dim)
        out, _ = self.lstm1(embedded)
        
        # input shape: (batch_size, seq_len, 2*rnn_size1)
        out, _ = self.lstm2(out)
        
        # input shape: (batch_size, seq_len, 2*hidden_size)
        pooled, _ = torch.max(out, dim=1)
        
        # input shape: (batch_size, 2*hidden_size)
        out = self.dropout(gelu(self.fc1(pooled)))
        
        # input shape: (batch_size, hidden_size)
        # output shape: (batch_size)
        return self.fc2(out).squeeze()

# %%
def process(model, loader, criterion, optim=None):
    epoch_loss, num_correct, total = 0, 0, 0
    preds, lbls = [], []
    
    for seq, lbl in loader:
        seq, lbl = seq.to(device), lbl.to(device)
        
        scores = model(seq)
        loss = criterion(scores, lbl)
        
        if optim is not None:
            optim.zero_grad()
            loss.backward()
            optim.step()
        
        epoch_loss += loss.item()
        num_correct += ((scores > 0) == lbl).sum().item()
        total += seq.shape[0]
        preds.extend(scores.detach().tolist())
        lbls.extend(lbl.detach().tolist())
    return epoch_loss / total, num_correct / total, roc_auc_score(lbls, preds)

# %%
# load train and dev data
train_seqs, train_lbl = read_data('../../data/c_train.csv')
dev_seqs, dev_lbl = read_data('../../data/c_val.csv')

# create vocab from train seqs
vocab = build_vocab_from_iterator(train_seqs, specials=['<UNK>'])
vocab.set_default_index(vocab['<UNK>'])
encode_text = lambda x: vocab(list(x))

# %%
NUM_EPOCHS = 30
VOCAB_SIZE = len(vocab)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def train(config, checkpoint_dir=None):
    
    # create train and dev loader
    train_data = CleavageDataset(train_seqs, train_lbl)
    train_loader = DataLoader(train_data, batch_size=512, shuffle=True, collate_fn=collate_train, num_workers=8)

    dev_data = CleavageDataset(dev_seqs, dev_lbl)
    dev_loader = DataLoader(dev_data, batch_size=512, shuffle=True, collate_fn=collate_dev, num_workers=8)
    
    
    model = BiLSTM(
        vocab_size=VOCAB_SIZE,
        embedding_dim=config['embedding_dim'],
        rnn_size1=config['rnn_size1'],
        rnn_size2=config['rnn_size2'],
        hidden_size=config['hidden_size'],
        dropout=config['dropout']
    ).to(device)
    
    optimizer = optim.Adam(model.parameters(), lr=config['lr'])
    criterion = nn.BCEWithLogitsLoss()
    
    # normal train loop
    for epoch in range(1, NUM_EPOCHS + 1):
        model.train()
        train_loss, train_acc, train_auc = process(model, train_loader, criterion, optimizer)
        
        model.eval()
        with torch.no_grad():
            val_loss, val_acc, val_auc = process(model, dev_loader, criterion)
        
        with tune.checkpoint_dir(step=epoch) as checkpoint_dir:
            checkpoint_path = os.path.join(checkpoint_dir, "checkpoint.pt")
            torch.save(model.state_dict(), checkpoint_path)
            
        # metrics that will be reported back to main process
        reg_auc = regularized_auc(train_auc, val_auc)
        
        tune.report(
            train_loss=train_loss,
            dev_loss=val_loss,
            train_acc=train_acc,
            dev_acc=val_acc,
            train_auc=train_auc,
            dev_auc=val_auc,
            reg_auc=reg_auc,
        )
        
        # if model is overfitting, stop the run
        if reg_auc == 0:
            break

# %%
class TuneReporter(CLIReporter):
    def __init__(self):
        super().__init__()
        self.num_terminated = 0

    def should_report(self, trials, done=False):
        """Reports only on trial termination events."""
        old_num_terminated = self.num_terminated
        self.num_terminated = len([t for t in trials if t.status == "TERMINATED"])
        return self.num_terminated > old_num_terminated
    
    def report(self, trials, done, *sys_info):
        print(self._progress_str(trials, done, *sys_info))
    
reporter = TuneReporter()
reporter.add_metric_column(metric='train_loss')
reporter.add_metric_column(metric='dev_loss')
reporter.add_metric_column(metric='train_acc')
reporter.add_metric_column(metric='dev_acc')
reporter.add_metric_column(metric='train_auc')
reporter.add_metric_column(metric='dev_auc')
reporter.add_metric_column(metric='reg_auc')

# %%
search_space = {
    'embedding_dim': tune.randint(50, 201),
    'rnn_size1': tune.randint(220, 281),
    'rnn_size2': tune.randint(450, 520),
    'hidden_size': tune.randint(120, 181),
    'dropout': tune.quniform(0.45, 0.52, 0.01),
    'lr': tune.choice([5e-5, 1e-4, 3e-4]),
}

# %%
path = '../../params/c_term/BiLSTM/'
experiment = 'search'
num_samples = 30

analysis = tune.run(
    train,
    name=experiment,
    config=search_space,
    sync_config=tune.SyncConfig(syncer=None),
    num_samples=num_samples,
    scheduler=ASHAScheduler(
        metric='reg_auc',
        mode='max',
        max_t=25,
        reduction_factor=2,
        grace_period=4
    ),
    progress_reporter=reporter,
    local_dir=path,
    keep_checkpoints_num=None, # keep all checkpoints
    checkpoint_score_attr='reg_auc',
    resume='AUTO',
    resources_per_trial={'cpu': 16, 'gpu': 1},
)
# Out:
# 2022-09-13 00:12:13,379	INFO trial_runner.py:510 -- No local checkpoint was found. Ray Tune will now start a new experiment.
# 2022-09-13 00:12:17,418	WARNING worker.py:1404 -- Warning: The actor ImplicitFunc is very large (21 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# Result for train_f4278_00000:
#   date: 2022-09-13_00-12-42
#   dev_acc: 0.8549559704121169
#   dev_auc: 0.8599539170996408
#   dev_loss: 0.0006487035507801428
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 1
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8599539170996408
#   should_checkpoint: true
#   time_since_restore: 23.76518750190735
#   time_this_iter_s: 23.76518750190735
#   time_total_s: 23.76518750190735
#   timestamp: 1663020762
#   timesteps_since_restore: 0
#   train_acc: 0.8279149102545701
#   train_auc: 0.7272859910955798
#   train_loss: 0.000810157033372806
#   training_iteration: 1
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-13-04
#   dev_acc: 0.8583867558999648
#   dev_auc: 0.8658633373369828
#   dev_loss: 0.0006359892783344695
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 2
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8658633373369828
#   should_checkpoint: true
#   time_since_restore: 45.37550687789917
#   time_this_iter_s: 21.61031937599182
#   time_total_s: 45.37550687789917
#   timestamp: 1663020784
#   timesteps_since_restore: 0
#   train_acc: 0.8465896032145093
#   train_auc: 0.8352484418951116
#   train_loss: 0.000685153387333862
#   training_iteration: 2
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-13-25
#   dev_acc: 0.8598661500528355
#   dev_auc: 0.8687518353018764
#   dev_loss: 0.000630360727013732
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 3
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8687518353018764
#   should_checkpoint: true
#   time_since_restore: 66.77769160270691
#   time_this_iter_s: 21.40218472480774
#   time_total_s: 66.77769160270691
#   timestamp: 1663020805
#   timesteps_since_restore: 0
#   train_acc: 0.8494841057730664
#   train_auc: 0.8419718815502618
#   train_loss: 0.0006736888600479342
#   training_iteration: 3
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-13-47
#   dev_acc: 0.8619654808030996
#   dev_auc: 0.8706477885712178
#   dev_loss: 0.00062431331449682
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 4
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8706477885712178
#   should_checkpoint: true
#   time_since_restore: 88.58517384529114
#   time_this_iter_s: 21.80748224258423
#   time_total_s: 88.58517384529114
#   timestamp: 1663020827
#   timesteps_since_restore: 0
#   train_acc: 0.8510145729001648
#   train_auc: 0.8453742524990371
#   train_loss: 0.0006674557379557299
#   training_iteration: 4
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-14-09
#   dev_acc: 0.8613244100035223
#   dev_auc: 0.8723549828949486
#   dev_loss: 0.0006238467152079213
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 5
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8723549828949486
#   should_checkpoint: true
#   time_since_restore: 111.1145555973053
#   time_this_iter_s: 22.52938175201416
#   time_total_s: 111.1145555973053
#   timestamp: 1663020849
#   timesteps_since_restore: 0
#   train_acc: 0.8522623703219705
#   train_auc: 0.8480753111088764
#   train_loss: 0.0006628091196839299
#   training_iteration: 5
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-14-32
#   dev_acc: 0.8628883409651286
#   dev_auc: 0.8738968372208362
#   dev_loss: 0.000618188623896616
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 6
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8738968372208362
#   should_checkpoint: true
#   time_since_restore: 133.9261770248413
#   time_this_iter_s: 22.81162142753601
#   time_total_s: 133.9261770248413
#   timestamp: 1663020872
#   timesteps_since_restore: 0
#   train_acc: 0.8533534225489411
#   train_auc: 0.8496094379558263
#   train_loss: 0.0006596870276757178
#   training_iteration: 6
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-14-55
#   dev_acc: 0.8640577668193026
#   dev_auc: 0.8745020644237118
#   dev_loss: 0.0006157314943234321
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 7
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8745020644237118
#   should_checkpoint: true
#   time_since_restore: 156.76278710365295
#   time_this_iter_s: 22.836610078811646
#   time_total_s: 156.76278710365295
#   timestamp: 1663020895
#   timesteps_since_restore: 0
#   train_acc: 0.8539513438258685
#   train_auc: 0.8511631887319779
#   train_loss: 0.0006568161973146614
#   training_iteration: 7
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-15-18
#   dev_acc: 0.864092990489609
#   dev_auc: 0.8756071489612489
#   dev_loss: 0.0006163790963744982
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 8
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8756071489612489
#   should_checkpoint: true
#   time_since_restore: 179.27759075164795
#   time_this_iter_s: 22.514803647994995
#   time_total_s: 179.27759075164795
#   timestamp: 1663020918
#   timesteps_since_restore: 0
#   train_acc: 0.8549886800029236
#   train_auc: 0.8525506354497405
#   train_loss: 0.0006540458673504975
#   training_iteration: 8
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-15-40
#   dev_acc: 0.8652271926734766
#   dev_auc: 0.8762345339328448
#   dev_loss: 0.0006123429690082546
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 9
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8762345339328448
#   should_checkpoint: true
#   time_since_restore: 201.61896896362305
#   time_this_iter_s: 22.341378211975098
#   time_total_s: 201.61896896362305
#   timestamp: 1663020940
#   timesteps_since_restore: 0
#   train_acc: 0.8554659603152868
#   train_auc: 0.8541996213920668
#   train_loss: 0.0006511982975293684
#   training_iteration: 9
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-16-02
#   dev_acc: 0.865530116238112
#   dev_auc: 0.8774202826633462
#   dev_loss: 0.000611748437240704
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 10
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8774202826633462
#   should_checkpoint: true
#   time_since_restore: 223.935124874115
#   time_this_iter_s: 22.316155910491943
#   time_total_s: 223.935124874115
#   timestamp: 1663020962
#   timesteps_since_restore: 0
#   train_acc: 0.8558692709851435
#   train_auc: 0.8549947681440939
#   train_loss: 0.0006496225380193332
#   training_iteration: 10
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-16-25
#   dev_acc: 0.8665304684748151
#   dev_auc: 0.8774556907642252
#   dev_loss: 0.0006092214011188627
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 11
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8774556907642252
#   should_checkpoint: true
#   time_since_restore: 246.80146288871765
#   time_this_iter_s: 22.86633801460266
#   time_total_s: 246.80146288871765
#   timestamp: 1663020985
#   timesteps_since_restore: 0
#   train_acc: 0.856078851638912
#   train_auc: 0.8556645025439468
#   train_loss: 0.0006485425586535738
#   training_iteration: 11
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-16-48
#   dev_acc: 0.865262416343783
#   dev_auc: 0.8780854476796183
#   dev_loss: 0.0006099096550493015
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 12
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8780854476796183
#   should_checkpoint: true
#   time_since_restore: 269.81274127960205
#   time_this_iter_s: 23.0112783908844
#   time_total_s: 269.81274127960205
#   timestamp: 1663021008
#   timesteps_since_restore: 0
#   train_acc: 0.8566494745953904
#   train_auc: 0.8563796932533374
#   train_loss: 0.0006467892178868728
#   training_iteration: 12
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-17-11
#   dev_acc: 0.8662627685804861
#   dev_auc: 0.8785912109326894
#   dev_loss: 0.0006077787316823854
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 13
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8785912109326894
#   should_checkpoint: true
#   time_since_restore: 292.67534375190735
#   time_this_iter_s: 22.862602472305298
#   time_total_s: 292.67534375190735
#   timestamp: 1663021031
#   timesteps_since_restore: 0
#   train_acc: 0.8571452473183803
#   train_auc: 0.857849156641776
#   train_loss: 0.0006442119440531399
#   training_iteration: 13
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-17-33
#   dev_acc: 0.8670235998591053
#   dev_auc: 0.8791070742774201
#   dev_loss: 0.0006078295838501135
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 14
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8791070742774201
#   should_checkpoint: true
#   time_since_restore: 314.4983367919922
#   time_this_iter_s: 21.82299304008484
#   time_total_s: 314.4983367919922
#   timestamp: 1663021053
#   timesteps_since_restore: 0
#   train_acc: 0.8571232325438248
#   train_auc: 0.8581095073325137
#   train_loss: 0.0006437064409359906
#   training_iteration: 14
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-17-55
#   dev_acc: 0.8674955970412117
#   dev_auc: 0.879650010672935
#   dev_loss: 0.000605391642290675
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 15
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.879650010672935
#   should_checkpoint: true
#   time_since_restore: 336.82785272598267
#   time_this_iter_s: 22.32951593399048
#   time_total_s: 336.82785272598267
#   timestamp: 1663021075
#   timesteps_since_restore: 0
#   train_acc: 0.8574261558417084
#   train_auc: 0.8583119081646536
#   train_loss: 0.0006431753406618497
#   training_iteration: 15
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-18-17
#   dev_acc: 0.8674815075730891
#   dev_auc: 0.8799733887228011
#   dev_loss: 0.0006044828204169749
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 16
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8799733887228011
#   should_checkpoint: true
#   time_since_restore: 358.7776794433594
#   time_this_iter_s: 21.94982671737671
#   time_total_s: 358.7776794433594
#   timestamp: 1663021097
#   timesteps_since_restore: 0
#   train_acc: 0.8581297480365022
#   train_auc: 0.8593709620514365
#   train_loss: 0.0006410031525176933
#   training_iteration: 16
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-18-39
#   dev_acc: 0.8677914758717858
#   dev_auc: 0.8798066564198357
#   dev_loss: 0.0006041746619890676
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 17
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8798066564198357
#   should_checkpoint: true
#   time_since_restore: 380.8368191719055
#   time_this_iter_s: 22.059139728546143
#   time_total_s: 380.8368191719055
#   timestamp: 1663021119
#   timesteps_since_restore: 0
#   train_acc: 0.8581517628110578
#   train_auc: 0.8597794998845238
#   train_loss: 0.0006405559073127285
#   training_iteration: 17
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-19-02
#   dev_acc: 0.8677280732652343
#   dev_auc: 0.880468504876987
#   dev_loss: 0.0006028669411214819
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 18
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.880468504876987
#   should_checkpoint: true
#   time_since_restore: 403.73069953918457
#   time_this_iter_s: 22.893880367279053
#   time_total_s: 403.73069953918457
#   timestamp: 1663021142
#   timesteps_since_restore: 0
#   train_acc: 0.8586237595775277
#   train_auc: 0.8605458377171562
#   train_loss: 0.0006386982516205635
#   training_iteration: 18
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-19-25
#   dev_acc: 0.8674110602324763
#   dev_auc: 0.8805197689120279
#   dev_loss: 0.0006045700696288133
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 19
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8805197689120279
#   should_checkpoint: true
#   time_since_restore: 426.57525873184204
#   time_this_iter_s: 22.84455919265747
#   time_total_s: 426.57525873184204
#   timestamp: 1663021165
#   timesteps_since_restore: 0
#   train_acc: 0.8587637735437007
#   train_auc: 0.8610627919509909
#   train_loss: 0.0006379427186809999
#   training_iteration: 19
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-19-48
#   dev_acc: 0.8679323705530116
#   dev_auc: 0.8807415124102653
#   dev_loss: 0.000602106939385835
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 20
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8807415124102653
#   should_checkpoint: true
#   time_since_restore: 449.7598195075989
#   time_this_iter_s: 23.184560775756836
#   time_total_s: 449.7598195075989
#   timestamp: 1663021188
#   timesteps_since_restore: 0
#   train_acc: 0.8591582783037353
#   train_auc: 0.8618237684094492
#   train_loss: 0.000636354157213598
#   training_iteration: 20
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-20-11
#   dev_acc: 0.8672138076787601
#   dev_auc: 0.8811418474228696
#   dev_loss: 0.0006050502210488073
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 21
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8811418474228696
#   should_checkpoint: true
#   time_since_restore: 472.53429770469666
#   time_this_iter_s: 22.77447819709778
#   time_total_s: 472.53429770469666
#   timestamp: 1663021211
#   timesteps_since_restore: 0
#   train_acc: 0.8594823357851922
#   train_auc: 0.8619562854907605
#   train_loss: 0.0006360118761365461
#   training_iteration: 21
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-20-33
#   dev_acc: 0.8680803099682987
#   dev_auc: 0.8814922257696975
#   dev_loss: 0.0006006486967400205
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 22
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8814922257696975
#   should_checkpoint: true
#   time_since_restore: 495.0185635089874
#   time_this_iter_s: 22.48426580429077
#   time_total_s: 495.0185635089874
#   timestamp: 1663021233
#   timesteps_since_restore: 0
#   train_acc: 0.8596064991136851
#   train_auc: 0.8625898838028964
#   train_loss: 0.0006348940540875524
#   training_iteration: 22
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-20-56
#   dev_acc: 0.8665938710813667
#   dev_auc: 0.8815815786301715
#   dev_loss: 0.0006059355196628657
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 23
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8815815786301715
#   should_checkpoint: true
#   time_since_restore: 517.7857029438019
#   time_this_iter_s: 22.767139434814453
#   time_total_s: 517.7857029438019
#   timestamp: 1663021256
#   timesteps_since_restore: 0
#   train_acc: 0.8599895561909509
#   train_auc: 0.8631311717039346
#   train_loss: 0.0006336887226058455
#   training_iteration: 23
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-21-19
#   dev_acc: 0.8682282493835858
#   dev_auc: 0.8816182504480221
#   dev_loss: 0.0006006255910698063
#   done: false
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 24
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8816182504480221
#   should_checkpoint: true
#   time_since_restore: 541.0098791122437
#   time_this_iter_s: 23.224176168441772
#   time_total_s: 541.0098791122437
#   timestamp: 1663021279
#   timesteps_since_restore: 0
#   train_acc: 0.8599966009188086
#   train_auc: 0.8635371380484428
#   train_loss: 0.0006330304407048642
#   training_iteration: 24
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# Result for train_f4278_00000:
#   date: 2022-09-13_00-21-43
#   dev_acc: 0.8671433603381472
#   dev_auc: 0.8814925981677499
#   dev_loss: 0.0006040254790583896
#   done: true
#   experiment_id: e0cbf5747f1d4bfebf0ab50b958ead9c
#   hostname: arch
#   iterations_since_restore: 25
#   node_ip: 192.168.178.26
#   pid: 126164
#   reg_auc: 0.8814925981677499
#   should_checkpoint: true
#   time_since_restore: 564.4981429576874
#   time_this_iter_s: 23.488263845443726
#   time_total_s: 564.4981429576874
#   timestamp: 1663021303
#   timesteps_since_restore: 0
#   train_acc: 0.8604879706868874
#   train_auc: 0.8638962155122188
#   train_loss: 0.0006322103442504408
#   training_iteration: 25
#   trial_id: f4278_00000
#   warmup_time: 0.0015697479248046875
#
# == Status ==
# Current time: 2022-09-13 00:21:43 (running for 00:09:29.93)
# Memory usage on this node: 9.8/31.3 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 16.000: 0.8799733887228011 | Iter 8.000: 0.8756071489612489 | Iter 4.000: 0.8706477885712178
# Resources requested: 0/24 CPUs, 0/1 GPUs, 0.0/16.9 GiB heap, 0.0/8.45 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /home/ingo/uni/cleavage_prediction/params/c_term/BiLSTM/search
# Number of trials: 27/30 (26 PENDING, 1 TERMINATED)
# +-------------------+------------+-----------------------+-----------+-----------------+---------------+--------+-------------+-------------+--------+------------------+--------------+-------------+-------------+-----------+-------------+-----------+-----------+
# | Trial name        | status     | loc                   |   dropout |   embedding_dim |   hidden_size |     lr |   rnn_size1 |   rnn_size2 |   iter |   total time (s) |   train_loss |    dev_loss |   train_acc |   dev_acc |   train_auc |   dev_auc |   reg_auc |
# |-------------------+------------+-----------------------+-----------+-----------------+---------------+--------+-------------+-------------+--------+------------------+--------------+-------------+-------------+-----------+-------------+-----------+-----------|
# | train_f4278_00001 | PENDING    |                       |      0.51 |              73 |           150 | 5e-05  |         261 |         476 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00002 | PENDING    |                       |      0.5  |             168 |           136 | 0.0003 |         278 |         519 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00003 | PENDING    |                       |      0.47 |             100 |           154 | 5e-05  |         268 |         487 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00004 | PENDING    |                       |      0.48 |             130 |           139 | 0.0003 |         223 |         452 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00005 | PENDING    |                       |      0.51 |             110 |           148 | 0.0001 |         262 |         496 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00006 | PENDING    |                       |      0.5  |             190 |           177 | 5e-05  |         225 |         481 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00007 | PENDING    |                       |      0.5  |              91 |           164 | 0.0003 |         228 |         506 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00008 | PENDING    |                       |      0.47 |              97 |           141 | 0.0001 |         269 |         468 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00009 | PENDING    |                       |      0.46 |             185 |           125 | 0.0003 |         256 |         517 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00010 | PENDING    |                       |      0.48 |             193 |           148 | 0.0001 |         254 |         460 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00011 | PENDING    |                       |      0.45 |             128 |           177 | 5e-05  |         243 |         500 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00012 | PENDING    |                       |      0.46 |             171 |           170 | 0.0001 |         254 |         483 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00013 | PENDING    |                       |      0.45 |             169 |           120 | 0.0001 |         259 |         502 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00014 | PENDING    |                       |      0.45 |              51 |           150 | 0.0001 |         234 |         453 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00015 | PENDING    |                       |      0.49 |              76 |           179 | 0.0003 |         252 |         518 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00016 | PENDING    |                       |      0.48 |             186 |           150 | 5e-05  |         264 |         474 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00017 | PENDING    |                       |      0.52 |             157 |           166 | 5e-05  |         222 |         517 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00018 | PENDING    |                       |      0.45 |             171 |           143 | 0.0003 |         262 |         452 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00019 | PENDING    |                       |      0.46 |             167 |           165 | 5e-05  |         237 |         458 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00000 | TERMINATED | 192.168.178.26:126164 |      0.48 |              97 |           173 | 5e-05  |         239 |         488 |     25 |          564.498 |   0.00063221 | 0.000604025 |    0.860488 |  0.867143 |    0.863896 |  0.881493 |  0.881493 |
# +-------------------+------------+-----------------------+-----------+-----------------+---------------+--------+-------------+-------------+--------+------------------+--------------+-------------+-------------+-----------+-------------+-----------+-----------+
# ... 7 more trials not shown (7 PENDING)
#
#
# Result for train_f4278_00001:
#   date: 2022-09-13_00-22-10
#   dev_acc: 0.8534836209933075
#   dev_auc: 0.8579683690210678
#   dev_loss: 0.0006536016570467813
#   done: false
#   experiment_id: e638c74b37a249a98e897caee5392479
#   hostname: arch
#   iterations_since_restore: 1
#   node_ip: 192.168.178.26
#   pid: 138205
#   reg_auc: 0.8579683690210678
#   should_checkpoint: true
#   time_since_restore: 24.88975954055786
#   time_this_iter_s: 24.88975954055786
#   time_total_s: 24.88975954055786
#   timestamp: 1663021330
#   timesteps_since_restore: 0
#   train_acc: 0.8297086740853522
#   train_auc: 0.7090975066823793
#   train_loss: 0.0008245986209317356
#   training_iteration: 1
#   trial_id: f4278_00001
#   warmup_time: 0.001687765121459961
#
# Result for train_f4278_00001:
#   date: 2022-09-13_00-22-33
#   dev_acc: 0.8582669954209229
#   dev_auc: 0.8652686704359908
#   dev_loss: 0.000636445825349365
#   done: false
#   experiment_id: e638c74b37a249a98e897caee5392479
#   hostname: arch
#   iterations_since_restore: 2
#   node_ip: 192.168.178.26
#   pid: 138205
#   reg_auc: 0.8652686704359908
#   should_checkpoint: true
#   time_since_restore: 47.98955011367798
#   time_this_iter_s: 23.099790573120117
#   time_total_s: 47.98955011367798
#   timestamp: 1663021353
#   timesteps_since_restore: 0
#   train_acc: 0.8455003121695032
#   train_auc: 0.830601914082085
#   train_loss: 0.000692397234630171
#   training_iteration: 2
#   trial_id: f4278_00001
#   warmup_time: 0.001687765121459961
#
# Result for train_f4278_00001:
#   date: 2022-09-13_00-22-56
#   dev_acc: 0.8589010214864389
#   dev_auc: 0.8676359305790351
#   dev_loss: 0.0006335132749368708
#   done: false
#   experiment_id: e638c74b37a249a98e897caee5392479
#   hostname: arch
#   iterations_since_restore: 3
#   node_ip: 192.168.178.26
#   pid: 138205
#   reg_auc: 0.8676359305790351
#   should_checkpoint: true
#   time_since_restore: 70.91163063049316
#   time_this_iter_s: 22.922080516815186
#   time_total_s: 70.91163063049316
#   timestamp: 1663021376
#   timesteps_since_restore: 0
#   train_acc: 0.8483833670452914
#   train_auc: 0.838749355847302
#   train_loss: 0.0006792735720529275
#   training_iteration: 3
#   trial_id: f4278_00001
#   warmup_time: 0.001687765121459961
#
# Result for train_f4278_00001:
#   date: 2022-09-13_00-23-19
#   dev_acc: 0.860366326171187
#   dev_auc: 0.8690643534056286
#   dev_loss: 0.0006286412307434244
#   done: true
#   experiment_id: e638c74b37a249a98e897caee5392479
#   hostname: arch
#   iterations_since_restore: 4
#   node_ip: 192.168.178.26
#   pid: 138205
#   reg_auc: 0.8690643534056286
#   should_checkpoint: true
#   time_since_restore: 94.21266913414001
#   time_this_iter_s: 23.30103850364685
#   time_total_s: 94.21266913414001
#   timestamp: 1663021399
#   timesteps_since_restore: 0
#   train_acc: 0.8500494451836517
#   train_auc: 0.8420658718265577
#   train_loss: 0.0006733217966400547
#   training_iteration: 4
#   trial_id: f4278_00001
#   warmup_time: 0.001687765121459961
#
# == Status ==
# Current time: 2022-09-13 00:23:19 (running for 00:11:05.96)
# Memory usage on this node: 9.4/31.3 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 16.000: 0.8799733887228011 | Iter 8.000: 0.8756071489612489 | Iter 4.000: 0.8698560709884232
# Resources requested: 0/24 CPUs, 0/1 GPUs, 0.0/16.9 GiB heap, 0.0/8.45 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /home/ingo/uni/cleavage_prediction/params/c_term/BiLSTM/search
# Number of trials: 28/30 (26 PENDING, 2 TERMINATED)
# +-------------------+------------+-----------------------+-----------+-----------------+---------------+--------+-------------+-------------+--------+------------------+--------------+-------------+-------------+-----------+-------------+-----------+-----------+
# | Trial name        | status     | loc                   |   dropout |   embedding_dim |   hidden_size |     lr |   rnn_size1 |   rnn_size2 |   iter |   total time (s) |   train_loss |    dev_loss |   train_acc |   dev_acc |   train_auc |   dev_auc |   reg_auc |
# |-------------------+------------+-----------------------+-----------+-----------------+---------------+--------+-------------+-------------+--------+------------------+--------------+-------------+-------------+-----------+-------------+-----------+-----------|
# | train_f4278_00002 | PENDING    |                       |      0.5  |             168 |           136 | 0.0003 |         278 |         519 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00003 | PENDING    |                       |      0.47 |             100 |           154 | 5e-05  |         268 |         487 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00004 | PENDING    |                       |      0.48 |             130 |           139 | 0.0003 |         223 |         452 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00005 | PENDING    |                       |      0.51 |             110 |           148 | 0.0001 |         262 |         496 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00006 | PENDING    |                       |      0.5  |             190 |           177 | 5e-05  |         225 |         481 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00007 | PENDING    |                       |      0.5  |              91 |           164 | 0.0003 |         228 |         506 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00008 | PENDING    |                       |      0.47 |              97 |           141 | 0.0001 |         269 |         468 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00009 | PENDING    |                       |      0.46 |             185 |           125 | 0.0003 |         256 |         517 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00010 | PENDING    |                       |      0.48 |             193 |           148 | 0.0001 |         254 |         460 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00011 | PENDING    |                       |      0.45 |             128 |           177 | 5e-05  |         243 |         500 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00012 | PENDING    |                       |      0.46 |             171 |           170 | 0.0001 |         254 |         483 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00013 | PENDING    |                       |      0.45 |             169 |           120 | 0.0001 |         259 |         502 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00014 | PENDING    |                       |      0.45 |              51 |           150 | 0.0001 |         234 |         453 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00015 | PENDING    |                       |      0.49 |              76 |           179 | 0.0003 |         252 |         518 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00016 | PENDING    |                       |      0.48 |             186 |           150 | 5e-05  |         264 |         474 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00017 | PENDING    |                       |      0.52 |             157 |           166 | 5e-05  |         222 |         517 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00018 | PENDING    |                       |      0.45 |             171 |           143 | 0.0003 |         262 |         452 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00019 | PENDING    |                       |      0.46 |             167 |           165 | 5e-05  |         237 |         458 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00000 | TERMINATED | 192.168.178.26:126164 |      0.48 |              97 |           173 | 5e-05  |         239 |         488 |     25 |         564.498  |  0.00063221  | 0.000604025 |    0.860488 |  0.867143 |    0.863896 |  0.881493 |  0.881493 |
# | train_f4278_00001 | TERMINATED | 192.168.178.26:138205 |      0.51 |              73 |           150 | 5e-05  |         261 |         476 |      4 |          94.2127 |  0.000673322 | 0.000628641 |    0.850049 |  0.860366 |    0.842066 |  0.869064 |  0.869064 |
# +-------------------+------------+-----------------------+-----------+-----------------+---------------+--------+-------------+-------------+--------+------------------+--------------+-------------+-------------+-----------+-------------+-----------+-----------+
# ... 8 more trials not shown (8 PENDING)
#
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-23-49
#   dev_acc: 0.8616343783022191
#   dev_auc: 0.8717434046217886
#   dev_loss: 0.0006234044632301989
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 1
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8717434046217886
#   should_checkpoint: true
#   time_since_restore: 28.721496105194092
#   time_this_iter_s: 28.721496105194092
#   time_total_s: 28.721496105194092
#   timestamp: 1663021429
#   timesteps_since_restore: 0
#   train_acc: 0.8452643137862682
#   train_auc: 0.8176147991442413
#   train_loss: 0.0007085292558224338
#   training_iteration: 1
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-24-17
#   dev_acc: 0.8638886932018316
#   dev_auc: 0.8767524773601094
#   dev_loss: 0.000615905125236041
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 2
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8767524773601094
#   should_checkpoint: true
#   time_since_restore: 56.51598501205444
#   time_this_iter_s: 27.79448890686035
#   time_total_s: 56.51598501205444
#   timestamp: 1663021457
#   timesteps_since_restore: 0
#   train_acc: 0.8550820226470389
#   train_auc: 0.852777208400745
#   train_loss: 0.0006540586776139813
#   training_iteration: 2
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-24-44
#   dev_acc: 0.8668827051778796
#   dev_auc: 0.8783097426374791
#   dev_loss: 0.0006073708951410251
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 3
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8783097426374791
#   should_checkpoint: true
#   time_since_restore: 83.25798559188843
#   time_this_iter_s: 26.742000579833984
#   time_total_s: 83.25798559188843
#   timestamp: 1663021484
#   timesteps_since_restore: 0
#   train_acc: 0.8570052333522074
#   train_auc: 0.857249056222319
#   train_loss: 0.0006454220439940826
#   training_iteration: 3
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-25-11
#   dev_acc: 0.8677069390630504
#   dev_auc: 0.880216458058262
#   dev_loss: 0.0006044191587093054
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 4
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.880216458058262
#   should_checkpoint: true
#   time_since_restore: 109.96690964698792
#   time_this_iter_s: 26.708924055099487
#   time_total_s: 109.96690964698792
#   timestamp: 1663021511
#   timesteps_since_restore: 0
#   train_acc: 0.8583701493746483
#   train_auc: 0.8597841777724622
#   train_loss: 0.0006403535852558212
#   training_iteration: 4
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-25-37
#   dev_acc: 0.8672912997534343
#   dev_auc: 0.8810376483836071
#   dev_loss: 0.0006048291120658504
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 5
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8810376483836071
#   should_checkpoint: true
#   time_since_restore: 136.58546042442322
#   time_this_iter_s: 26.618550777435303
#   time_total_s: 136.58546042442322
#   timestamp: 1663021537
#   timesteps_since_restore: 0
#   train_acc: 0.8590710997964954
#   train_auc: 0.8617624226965542
#   train_loss: 0.000636718161214752
#   training_iteration: 5
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-26-05
#   dev_acc: 0.8687284255019373
#   dev_auc: 0.8818148730666382
#   dev_loss: 0.0006000448947601144
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 6
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8818148730666382
#   should_checkpoint: true
#   time_since_restore: 164.5139238834381
#   time_this_iter_s: 27.928463459014893
#   time_total_s: 164.5139238834381
#   timestamp: 1663021565
#   timesteps_since_restore: 0
#   train_acc: 0.8601885697529326
#   train_auc: 0.8635050569337357
#   train_loss: 0.0006331767774452517
#   training_iteration: 6
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-26-32
#   dev_acc: 0.8686157097569567
#   dev_auc: 0.8823721350281256
#   dev_loss: 0.000599244358191905
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 7
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8823721350281256
#   should_checkpoint: true
#   time_since_restore: 191.6212821006775
#   time_this_iter_s: 27.10735821723938
#   time_total_s: 191.6212821006775
#   timestamp: 1663021592
#   timesteps_since_restore: 0
#   train_acc: 0.8607072378414602
#   train_auc: 0.864584790017084
#   train_loss: 0.0006310312225707611
#   training_iteration: 7
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-26-59
#   dev_acc: 0.8691088411412469
#   dev_auc: 0.8829270379046308
#   dev_loss: 0.0005979976808575519
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 8
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8829270379046308
#   should_checkpoint: true
#   time_since_restore: 218.42701983451843
#   time_this_iter_s: 26.805737733840942
#   time_total_s: 218.42701983451843
#   timestamp: 1663021619
#   timesteps_since_restore: 0
#   train_acc: 0.8616582761022578
#   train_auc: 0.8663665580238803
#   train_loss: 0.0006272587708209863
#   training_iteration: 8
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-27-26
#   dev_acc: 0.8690031701303276
#   dev_auc: 0.8826856791299653
#   dev_loss: 0.0005988308037826401
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 9
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8826856791299653
#   should_checkpoint: true
#   time_since_restore: 245.2626485824585
#   time_this_iter_s: 26.835628747940063
#   time_total_s: 245.2626485824585
#   timestamp: 1663021646
#   timesteps_since_restore: 0
#   train_acc: 0.8620519002713101
#   train_auc: 0.8674458600116469
#   train_loss: 0.0006251891950188448
#   training_iteration: 9
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-27-53
#   dev_acc: 0.8678337442761536
#   dev_auc: 0.8830835621695678
#   dev_loss: 0.0005983905794965671
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 10
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8830835621695678
#   should_checkpoint: true
#   time_since_restore: 272.12998938560486
#   time_this_iter_s: 26.867340803146362
#   time_total_s: 272.12998938560486
#   timestamp: 1663021673
#   timesteps_since_restore: 0
#   train_acc: 0.8625230164467977
#   train_auc: 0.8693988702400524
#   train_loss: 0.0006215845245408529
#   training_iteration: 10
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-28-20
#   dev_acc: 0.8687988728425502
#   dev_auc: 0.8835339893730915
#   dev_loss: 0.0005973617565090197
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 11
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8835339893730915
#   should_checkpoint: true
#   time_since_restore: 298.9979820251465
#   time_this_iter_s: 26.867992639541626
#   time_total_s: 298.9979820251465
#   timestamp: 1663021700
#   timesteps_since_restore: 0
#   train_acc: 0.8633243542406179
#   train_auc: 0.8706352660364445
#   train_loss: 0.0006189744512542034
#   training_iteration: 11
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-28-47
#   dev_acc: 0.8687918281084889
#   dev_auc: 0.8836426018622399
#   dev_loss: 0.0005991113134444957
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 12
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8836426018622399
#   should_checkpoint: true
#   time_since_restore: 326.39174365997314
#   time_this_iter_s: 27.39376163482666
#   time_total_s: 326.39174365997314
#   timestamp: 1663021727
#   timesteps_since_restore: 0
#   train_acc: 0.8642498553629312
#   train_auc: 0.8723573255849999
#   train_loss: 0.0006155039105685309
#   training_iteration: 12
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-29-14
#   dev_acc: 0.8685029940119761
#   dev_auc: 0.8826489196691384
#   dev_loss: 0.0006011615455801448
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 13
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8826489196691384
#   should_checkpoint: true
#   time_since_restore: 353.5605592727661
#   time_this_iter_s: 27.16881561279297
#   time_total_s: 353.5605592727661
#   timestamp: 1663021754
#   timesteps_since_restore: 0
#   train_acc: 0.8649120597815606
#   train_auc: 0.8739554533766448
#   train_loss: 0.0006122758014188171
#   training_iteration: 13
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-29-42
#   dev_acc: 0.8687495597041212
#   dev_auc: 0.8829640071671774
#   dev_loss: 0.0006013083484190457
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 14
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8829640071671774
#   should_checkpoint: true
#   time_since_restore: 381.15894532203674
#   time_this_iter_s: 27.59838604927063
#   time_total_s: 381.15894532203674
#   timestamp: 1663021782
#   timesteps_since_restore: 0
#   train_acc: 0.8657266064401141
#   train_auc: 0.875616213819752
#   train_loss: 0.000608947306478258
#   training_iteration: 14
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-30-09
#   dev_acc: 0.8679041916167665
#   dev_auc: 0.8822096677910878
#   dev_loss: 0.000598529304216008
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 15
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8822096677910878
#   should_checkpoint: true
#   time_since_restore: 408.22761249542236
#   time_this_iter_s: 27.06866717338562
#   time_total_s: 408.22761249542236
#   timestamp: 1663021809
#   timesteps_since_restore: 0
#   train_acc: 0.8665631678732231
#   train_auc: 0.877702730595735
#   train_loss: 0.0006047632749542918
#   training_iteration: 15
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-30-36
#   dev_acc: 0.8671504050722085
#   dev_auc: 0.8813347000399385
#   dev_loss: 0.0006072658563886322
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 16
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8813347000399385
#   should_checkpoint: true
#   time_since_restore: 435.1011309623718
#   time_this_iter_s: 26.873518466949463
#   time_total_s: 435.1011309623718
#   timestamp: 1663021836
#   timesteps_since_restore: 0
#   train_acc: 0.8671144178280928
#   train_auc: 0.8791520055890787
#   train_loss: 0.0006016711904020071
#   training_iteration: 16
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-31-03
#   dev_acc: 0.8679464600211342
#   dev_auc: 0.8821196645452827
#   dev_loss: 0.000606169916240629
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 17
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0.8821196645452827
#   should_checkpoint: true
#   time_since_restore: 462.5316216945648
#   time_this_iter_s: 27.430490732192993
#   time_total_s: 462.5316216945648
#   timestamp: 1663021863
#   timesteps_since_restore: 0
#   train_acc: 0.8677924728844022
#   train_auc: 0.8812666924085483
#   train_loss: 0.0005972741417963511
#   training_iteration: 17
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-31-30
#   dev_acc: 0.8671715392743924
#   dev_auc: 0.8809553995108794
#   dev_loss: 0.0006029119480869727
#   done: false
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   hostname: arch
#   iterations_since_restore: 18
#   node_ip: 192.168.178.26
#   pid: 140115
#   reg_auc: 0
#   should_checkpoint: true
#   time_since_restore: 489.371169090271
#   time_this_iter_s: 26.839547395706177
#   time_total_s: 489.371169090271
#   timestamp: 1663021890
#   timesteps_since_restore: 0
#   train_acc: 0.8689372411612881
#   train_auc: 0.8834763025426301
#   train_loss: 0.0005927835987084473
#   training_iteration: 18
#   trial_id: f4278_00002
#   warmup_time: 0.001676797866821289
#
# Result for train_f4278_00002:
#   date: 2022-09-13_00-31-30
#   dev_acc: 0.8671715392743924
#   dev_auc: 0.8809553995108794
#   dev_loss: 0.0006029119480869727
#   done: true
#   experiment_id: a55600a741ed45a6a3c73b941cd8f6c9
#   experiment_tag: 2_dropout=0.5000,embedding_dim=168,hidden_size=136,lr=0.0003,rnn_size1=278,rnn_size2=519
#   hostname: arch
#   iterations_since_restore: 18
#   node_ip: 192.168.178.26
#   pid: 140115
# ...
# | Trial name        | status     | loc                   |   dropout |   embedding_dim |   hidden_size |     lr |   rnn_size1 |   rnn_size2 |   iter |   total time (s) |   train_loss |    dev_loss |   train_acc |   dev_acc |   train_auc |   dev_auc |   reg_auc |
# |-------------------+------------+-----------------------+-----------+-----------------+---------------+--------+-------------+-------------+--------+------------------+--------------+-------------+-------------+-----------+-------------+-----------+-----------|
# | train_f4278_00029 | PENDING    |                       |      0.5  |             110 |           180 | 0.0001 |         239 |         459 |        |                  |              |             |             |           |             |           |           |
# | train_f4278_00000 | TERMINATED | 192.168.178.26:126164 |      0.48 |              97 |           173 | 5e-05  |         239 |         488 |     25 |         564.498  |  0.00063221  | 0.000604025 |    0.860488 |  0.867143 |    0.863896 |  0.881493 |  0.881493 |
# | train_f4278_00001 | TERMINATED | 192.168.178.26:138205 |      0.51 |              73 |           150 | 5e-05  |         261 |         476 |      4 |          94.2127 |  0.000673322 | 0.000628641 |    0.850049 |  0.860366 |    0.842066 |  0.869064 |  0.869064 |
# | train_f4278_00002 | TERMINATED | 192.168.178.26:140115 |      0.5  |             168 |           136 | 0.0003 |         278 |         519 |     18 |         489.371  |  0.000592784 | 0.000602912 |    0.868937 |  0.867172 |    0.883476 |  0.880955 |  0        |
# | train_f4278_00003 | TERMINATED | 192.168.178.26:148689 |      0.47 |             100 |           154 | 5e-05  |         268 |         487 |      8 |         192.666  |  0.000651285 | 0.000612825 |    0.855359 |  0.865009 |    0.854192 |  0.876475 |  0.876475 |
# | train_f4278_00004 | TERMINATED | 192.168.178.26:152465 |      0.48 |             130 |           139 | 0.0003 |         223 |         452 |     20 |         434.041  |  0.000591336 | 0.000608009 |    0.869193 |  0.866847 |    0.884021 |  0.879767 |  0        |
# | train_f4278_00005 | TERMINATED | 192.168.178.26:162421 |      0.51 |             110 |           148 | 0.0001 |         262 |         496 |      8 |         189.999  |  0.000642902 | 0.000609169 |    0.857559 |  0.866608 |    0.858505 |  0.879146 |  0.879146 |
# | train_f4278_00006 | TERMINATED | 192.168.178.26:166338 |      0.5  |             190 |           177 | 5e-05  |         225 |         481 |      4 |          94.8155 |  0.000659442 | 0.000621468 |    0.853513 |  0.86224  |    0.849875 |  0.872582 |  0.872582 |
# | train_f4278_00007 | TERMINATED | 192.168.178.26:168471 |      0.5  |              91 |           164 | 0.0003 |         228 |         506 |     20 |         470.77   |  0.000593019 | 0.000606541 |    0.868375 |  0.868158 |    0.883402 |  0.88086  |  0        |
# | train_f4278_00008 | TERMINATED | 192.168.178.26:178898 |      0.47 |              97 |           141 | 0.0001 |         269 |         468 |      8 |         195.972  |  0.000642968 | 0.000606105 |    0.857705 |  0.867672 |    0.858426 |  0.879726 |  0.879726 |
# | train_f4278_00009 | TERMINATED | 192.168.178.26:183044 |      0.46 |             185 |           125 | 0.0003 |         256 |         517 |     18 |         462.345  |  0.000588561 | 0.000605429 |    0.869864 |  0.867784 |    0.885398 |  0.879984 |  0        |
# | train_f4278_00010 | TERMINATED | 192.168.178.26:192612 |      0.48 |             193 |           148 | 0.0001 |         254 |         460 |      8 |         189.26   |  0.000638535 | 0.000608827 |    0.858549 |  0.865234 |    0.860784 |  0.879685 |  0.879685 |
# | train_f4278_00011 | TERMINATED | 192.168.178.26:196940 |      0.45 |             128 |           177 | 5e-05  |         243 |         500 |      4 |          98.18   |  0.000662364 | 0.000622223 |    0.852483 |  0.861789 |    0.848261 |  0.872389 |  0.872389 |
# | train_f4278_00012 | TERMINATED | 192.168.178.26:199101 |      0.46 |             171 |           170 | 0.0001 |         254 |         483 |     25 |         624.825  |  0.000603547 | 0.000601974 |    0.867068 |  0.867489 |    0.877974 |  0.88196  |  0.88196  |
# | train_f4278_00013 | TERMINATED | 192.168.178.26:211801 |      0.45 |             169 |           120 | 0.0001 |         259 |         502 |     25 |         660.404  |  0.000602476 | 0.000602753 |    0.867285 |  0.867925 |    0.878521 |  0.881309 |  0.881309 |
# | train_f4278_00014 | TERMINATED | 192.168.178.26:224285 |      0.45 |              51 |           150 | 0.0001 |         234 |         453 |      4 |          91.8829 |  0.00066616  | 0.000620667 |    0.851759 |  0.862966 |    0.846094 |  0.872559 |  0.872559 |
# | train_f4278_00015 | TERMINATED | 192.168.178.26:226225 |      0.49 |              76 |           179 | 0.0003 |         252 |         518 |     21 |         526.32   |  0.000588631 | 0.000603876 |    0.869212 |  0.868778 |    0.885415 |  0.880737 |  0        |
# | train_f4278_00016 | TERMINATED | 192.168.178.26:236209 |      0.48 |             186 |           150 | 5e-05  |         264 |         474 |      4 |          99.1086 |  0.000659514 | 0.000623883 |    0.853296 |  0.861599 |    0.849842 |  0.872706 |  0.872706 |
# | train_f4278_00017 | TERMINATED | 192.168.178.26:238119 |      0.52 |             157 |           166 | 5e-05  |         222 |         517 |      4 |         100.137  |  0.000663143 | 0.000621978 |    0.852357 |  0.862078 |    0.847952 |  0.872289 |  0.872289 |
# | train_f4278_00018 | TERMINATED | 192.168.178.26:240039 |      0.45 |             171 |           143 | 0.0003 |         262 |         452 |     16 |         365.078  |  0.000600888 | 0.000599942 |    0.867134 |  0.869017 |    0.879424 |  0.882019 |  0.882019 |
# +-------------------+------------+-----------------------+-----------+-----------------+---------------+--------+-------------+-------------+--------+------------------+--------------+-------------+-------------+-----------+-------------+-----------+-----------+
# ... 10 more trials not shown (10 TERMINATED)
#
#
# Result for train_f4278_00029:
#   date: 2022-09-13_02-32-45
#   dev_acc: 0.8558295174357168
#   dev_auc: 0.8651791240165108
#   dev_loss: 0.0006440774340073632
#   done: false
#   experiment_id: c2dfcaf332a4485f89dae982ddf623aa
#   hostname: arch
#   iterations_since_restore: 1
#   node_ip: 192.168.178.26
#   pid: 296259
#   reg_auc: 0.8651791240165108
#   should_checkpoint: true
#   time_since_restore: 24.29780340194702
#   time_this_iter_s: 24.29780340194702
#   time_total_s: 24.29780340194702
#   timestamp: 1663029165
#   timesteps_since_restore: 0
#   train_acc: 0.8384494201748678
#   train_auc: 0.7838919413369554
#   train_loss: 0.0007514044929042274
#   training_iteration: 1
#   trial_id: f4278_00029
#   warmup_time: 0.001775979995727539
#
# Result for train_f4278_00029:
#   date: 2022-09-13_02-33-08
#   dev_acc: 0.8616696019725255
#   dev_auc: 0.8713051284909297
#   dev_loss: 0.0006238577042763062
#   done: false
#   experiment_id: c2dfcaf332a4485f89dae982ddf623aa
#   hostname: arch
#   iterations_since_restore: 2
#   node_ip: 192.168.178.26
#   pid: 296259
#   reg_auc: 0.8713051284909297
#   should_checkpoint: true
#   time_since_restore: 47.25321555137634
#   time_this_iter_s: 22.95541214942932
#   time_total_s: 47.25321555137634
#   timestamp: 1663029188
#   timesteps_since_restore: 0
#   train_acc: 0.8502114739243801
#   train_auc: 0.8433878950566351
#   train_loss: 0.0006710511837360295
#   training_iteration: 2
#   trial_id: f4278_00029
#   warmup_time: 0.001775979995727539
#
# Result for train_f4278_00029:
#   date: 2022-09-13_02-33-30
#   dev_acc: 0.8626629094751673
#   dev_auc: 0.8734557957679556
#   dev_loss: 0.0006195386394979081
#   done: false
#   experiment_id: c2dfcaf332a4485f89dae982ddf623aa
#   hostname: arch
#   iterations_since_restore: 3
#   node_ip: 192.168.178.26
#   pid: 296259
#   reg_auc: 0.8734557957679556
#   should_checkpoint: true
#   time_since_restore: 69.42790484428406
#   time_this_iter_s: 22.174689292907715
#   time_total_s: 69.42790484428406
#   timestamp: 1663029210
#   timesteps_since_restore: 0
#   train_acc: 0.8525837860304808
#   train_auc: 0.8483711613493836
#   train_loss: 0.0006621430596224722
#   training_iteration: 3
#   trial_id: f4278_00029
#   warmup_time: 0.001775979995727539
# 2022-09-13 02:33:53,122	INFO tune.py:747 -- Total run time: 8500.03 seconds (8499.63 seconds for the tuning loop).
# Result for train_f4278_00029:
#   date: 2022-09-13_02-33-53
#   dev_acc: 0.8639520958083833
#   dev_auc: 0.8751064043683472
#   dev_loss: 0.0006151625299882032
#   done: true
#   experiment_id: c2dfcaf332a4485f89dae982ddf623aa
#   hostname: arch
#   iterations_since_restore: 4
#   node_ip: 192.168.178.26
#   pid: 296259
#   reg_auc: 0.8751064043683472
#   should_checkpoint: true
#   time_since_restore: 92.2470932006836
#   time_this_iter_s: 22.819188356399536
#   time_total_s: 92.2470932006836
#   timestamp: 1663029233
#   timesteps_since_restore: 0
#   train_acc: 0.854462086595556
#   train_auc: 0.852047220499412
#   train_loss: 0.0006553527197399174
#   training_iteration: 4
#   trial_id: f4278_00029
#   warmup_time: 0.001775979995727539
#
# == Status ==
# Current time: 2022-09-13 02:33:53 (running for 02:21:39.63)
# Memory usage on this node: 9.6/31.3 GiB
# Using AsyncHyperBand: num_stopped=25
# Bracket: Iter 16.000: 0.8823495743216672 | Iter 8.000: 0.8803121063238868 | Iter 4.000: 0.8754318273927981
# Resources requested: 0/24 CPUs, 0/1 GPUs, 0.0/16.9 GiB heap, 0.0/8.45 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /home/ingo/uni/cleavage_prediction/params/c_term/BiLSTM/search
# Number of trials: 30/30 (30 TERMINATED)
# +-------------------+------------+-----------------------+-----------+-----------------+---------------+--------+-------------+-------------+--------+------------------+--------------+-------------+-------------+-----------+-------------+-----------+-----------+
# | Trial name        | status     | loc                   |   dropout |   embedding_dim |   hidden_size |     lr |   rnn_size1 |   rnn_size2 |   iter |   total time (s) |   train_loss |    dev_loss |   train_acc |   dev_acc |   train_auc |   dev_auc |   reg_auc |
# |-------------------+------------+-----------------------+-----------+-----------------+---------------+--------+-------------+-------------+--------+------------------+--------------+-------------+-------------+-----------+-------------+-----------+-----------|
# | train_f4278_00000 | TERMINATED | 192.168.178.26:126164 |      0.48 |              97 |           173 | 5e-05  |         239 |         488 |     25 |         564.498  |  0.00063221  | 0.000604025 |    0.860488 |  0.867143 |    0.863896 |  0.881493 |  0.881493 |
# | train_f4278_00001 | TERMINATED | 192.168.178.26:138205 |      0.51 |              73 |           150 | 5e-05  |         261 |         476 |      4 |          94.2127 |  0.000673322 | 0.000628641 |    0.850049 |  0.860366 |    0.842066 |  0.869064 |  0.869064 |
# | train_f4278_00002 | TERMINATED | 192.168.178.26:140115 |      0.5  |             168 |           136 | 0.0003 |         278 |         519 |     18 |         489.371  |  0.000592784 | 0.000602912 |    0.868937 |  0.867172 |    0.883476 |  0.880955 |  0        |
# | train_f4278_00003 | TERMINATED | 192.168.178.26:148689 |      0.47 |             100 |           154 | 5e-05  |         268 |         487 |      8 |         192.666  |  0.000651285 | 0.000612825 |    0.855359 |  0.865009 |    0.854192 |  0.876475 |  0.876475 |
# | train_f4278_00004 | TERMINATED | 192.168.178.26:152465 |      0.48 |             130 |           139 | 0.0003 |         223 |         452 |     20 |         434.041  |  0.000591336 | 0.000608009 |    0.869193 |  0.866847 |    0.884021 |  0.879767 |  0        |
# | train_f4278_00005 | TERMINATED | 192.168.178.26:162421 |      0.51 |             110 |           148 | 0.0001 |         262 |         496 |      8 |         189.999  |  0.000642902 | 0.000609169 |    0.857559 |  0.866608 |    0.858505 |  0.879146 |  0.879146 |
# | train_f4278_00006 | TERMINATED | 192.168.178.26:166338 |      0.5  |             190 |           177 | 5e-05  |         225 |         481 |      4 |          94.8155 |  0.000659442 | 0.000621468 |    0.853513 |  0.86224  |    0.849875 |  0.872582 |  0.872582 |
# | train_f4278_00007 | TERMINATED | 192.168.178.26:168471 |      0.5  |              91 |           164 | 0.0003 |         228 |         506 |     20 |         470.77   |  0.000593019 | 0.000606541 |    0.868375 |  0.868158 |    0.883402 |  0.88086  |  0        |
# | train_f4278_00008 | TERMINATED | 192.168.178.26:178898 |      0.47 |              97 |           141 | 0.0001 |         269 |         468 |      8 |         195.972  |  0.000642968 | 0.000606105 |    0.857705 |  0.867672 |    0.858426 |  0.879726 |  0.879726 |
# | train_f4278_00009 | TERMINATED | 192.168.178.26:183044 |      0.46 |             185 |           125 | 0.0003 |         256 |         517 |     18 |         462.345  |  0.000588561 | 0.000605429 |    0.869864 |  0.867784 |    0.885398 |  0.879984 |  0        |
# | train_f4278_00010 | TERMINATED | 192.168.178.26:192612 |      0.48 |             193 |           148 | 0.0001 |         254 |         460 |      8 |         189.26   |  0.000638535 | 0.000608827 |    0.858549 |  0.865234 |    0.860784 |  0.879685 |  0.879685 |
# | train_f4278_00011 | TERMINATED | 192.168.178.26:196940 |      0.45 |             128 |           177 | 5e-05  |         243 |         500 |      4 |          98.18   |  0.000662364 | 0.000622223 |    0.852483 |  0.861789 |    0.848261 |  0.872389 |  0.872389 |
# | train_f4278_00012 | TERMINATED | 192.168.178.26:199101 |      0.46 |             171 |           170 | 0.0001 |         254 |         483 |     25 |         624.825  |  0.000603547 | 0.000601974 |    0.867068 |  0.867489 |    0.877974 |  0.88196  |  0.88196  |
# | train_f4278_00013 | TERMINATED | 192.168.178.26:211801 |      0.45 |             169 |           120 | 0.0001 |         259 |         502 |     25 |         660.404  |  0.000602476 | 0.000602753 |    0.867285 |  0.867925 |    0.878521 |  0.881309 |  0.881309 |
# | train_f4278_00014 | TERMINATED | 192.168.178.26:224285 |      0.45 |              51 |           150 | 0.0001 |         234 |         453 |      4 |          91.8829 |  0.00066616  | 0.000620667 |    0.851759 |  0.862966 |    0.846094 |  0.872559 |  0.872559 |
# | train_f4278_00015 | TERMINATED | 192.168.178.26:226225 |      0.49 |              76 |           179 | 0.0003 |         252 |         518 |     21 |         526.32   |  0.000588631 | 0.000603876 |    0.869212 |  0.868778 |    0.885415 |  0.880737 |  0        |
# | train_f4278_00016 | TERMINATED | 192.168.178.26:236209 |      0.48 |             186 |           150 | 5e-05  |         264 |         474 |      4 |          99.1086 |  0.000659514 | 0.000623883 |    0.853296 |  0.861599 |    0.849842 |  0.872706 |  0.872706 |
# | train_f4278_00017 | TERMINATED | 192.168.178.26:238119 |      0.52 |             157 |           166 | 5e-05  |         222 |         517 |      4 |         100.137  |  0.000663143 | 0.000621978 |    0.852357 |  0.862078 |    0.847952 |  0.872289 |  0.872289 |
# | train_f4278_00018 | TERMINATED | 192.168.178.26:240039 |      0.45 |             171 |           143 | 0.0003 |         262 |         452 |     16 |         365.078  |  0.000600888 | 0.000599942 |    0.867134 |  0.869017 |    0.879424 |  0.882019 |  0.882019 |
# | train_f4278_00019 | TERMINATED | 192.168.178.26:247598 |      0.46 |             167 |           165 | 5e-05  |         237 |         458 |      4 |          92.6233 |  0.000659542 | 0.000620563 |    0.853259 |  0.863212 |    0.849836 |  0.872911 |  0.872911 |
# +-------------------+------------+-----------------------+-----------+-----------------+---------------+--------+-------------+-------------+--------+------------------+--------------+-------------+-------------+-----------+-------------+-----------+-----------+
# ... 10 more trials not shown (10 TERMINATED)

# %%
ana = ExperimentAnalysis(path + experiment)
# Out:
# 2022-09-13 02:33:53,198	INFO experiment_analysis.py:757 -- No `self.trials`. Drawing logdirs from checkpoint file. This may result in some information that is out of sync, as checkpointing is periodic.

# %%
df = ana.dataframe()
cols_needed = [col for col in df.columns if col.startswith('config/')]

# %%
df[['train_auc', 'dev_auc', 'reg_auc', 'training_iteration', *cols_needed]].sort_values(by='reg_auc', ascending=False)
# Out:
#     train_auc   dev_auc   reg_auc  training_iteration  config/dropout  \
# 0    0.874430  0.882703  0.882703                  25            0.51
# 2    0.879424  0.882019  0.882019                  16            0.45
# 26   0.876672  0.881982  0.881982                  25            0.49
# 21   0.877974  0.881960  0.881960                  25            0.46
# 28   0.878873  0.881920  0.881920                  16            0.47
# 23   0.863896  0.881493  0.881493                  25            0.48
# 12   0.878521  0.881309  0.881309                  25            0.45
# 27   0.859582  0.879939  0.879939                   8            0.46
# 5    0.858426  0.879726  0.879726                   8            0.47
# 20   0.860784  0.879685  0.879685                   8            0.48
# 19   0.858253  0.879529  0.879529                   8            0.46
# 9    0.858505  0.879146  0.879146                   8            0.51
# 13   0.854192  0.876475  0.876475                   8            0.47
# 17   0.853022  0.875344  0.875344                   4            0.47
# 29   0.852047  0.875106  0.875106                   4            0.50
# 24   0.850315  0.874854  0.874854                   4            0.49
# 1    0.849836  0.872911  0.872911                   4            0.46
# 11   0.849842  0.872706  0.872706                   4            0.48
# 8    0.849875  0.872582  0.872582                   4            0.50
# 16   0.846094  0.872559  0.872559                   4            0.45
# 22   0.848261  0.872389  0.872389                   4            0.45
# 25   0.847952  0.872289  0.872289                   4            0.52
# 15   0.847904  0.871296  0.871296                   4            0.50
# 4    0.843235  0.869862  0.869862                   4            0.52
# 10   0.842066  0.869064  0.869064                   4            0.51
# 14   0.883476  0.880955  0.000000                  18            0.50
# 18   0.885415  0.880737  0.000000                  21            0.49
# 7    0.885398  0.879984  0.000000                  18            0.46
# 6    0.883402  0.880860  0.000000                  20            0.50
# 3    0.884021  0.879767  0.000000                  20            0.48
#
#     config/embedding_dim  config/hidden_size  config/lr  config/rnn_size1  \
# 0                    111                 169    0.00010               269
# 2                    171                 143    0.00030               262
# 26                   198                 122    0.00010               246
# 21                   171                 170    0.00010               254
# 28                   169                 168    0.00030               233
# 23                    97                 173    0.00005               239
# 12                   169                 120    0.00010               259
# 27                   118                 162    0.00010               247
# 5                     97                 141    0.00010               269
# 20                   193                 148    0.00010               254
# 19                    97                 165    0.00010               243
# 9                    110                 148    0.00010               262
# 13                   100                 154    0.00005               268
# 17                   134                 131    0.00010               248
# 29                   110                 180    0.00010               239
# 24                    89                 179    0.00010               237
# 1                    167                 165    0.00005               237
# 11                   186                 150    0.00005               264
# 8                    190                 177    0.00005               225
# 16                    51                 150    0.00010               234
# 22                   128                 177    0.00005               243
# 25                   157                 166    0.00005               222
# 15                   148                 159    0.00005               245
# 4                     88                 137    0.00005               228
# 10                    73                 150    0.00005               261
# 14                   168                 136    0.00030               278
# 18                    76                 179    0.00030               252
# 7                    185                 125    0.00030               256
# 6                     91                 164    0.00030               228
# 3                    130                 139    0.00030               223
#
#     config/rnn_size2
# 0                507
# 2                452
# 26               473
# 21               483
# 28               506
# 23               488
# 12               502
# 27               510
# 5                468
# 20               460
# 19               475
# 9                496
# 13               487
# 17               451
# 29               459
# 24               489
# 1                458
# 11               474
# 8                481
# 16               453
# 22               500
# 25               517
# 15               506
# 4                504
# 10               476
# 14               519
# 18               518
# 7                517
# 6                506
# 3                452

# %%
### when the acc suddenly drops to zero, that's when the model started to overfit stronger than the threshold (default=0.0025) 
plt.figure(figsize=(16, 9))
ax = None
for val in ana.trial_dataframes.values():
    ax = val.reg_auc.plot(ax=ax, legend=False)
plt.xlabel('Epochs')
plt.ylabel('Regularized AUC')
plt.suptitle('Overview of Hyperparameter Search: BiLSTM (c_term)', fontsize=15, ha='center')
plt.title("In cases of sudden AUC drops to zero, the model started to overfit stronger than the threshold (default=0.0025)", fontsize=12, ha='center')
plt.tight_layout()
plt.show()
