# %% [markdown]
# # Sources
# * BiLSTM model architecture based on [Ozols et. al., 2021](https://www.mdpi.com/1422-0067/22/6/3071/htm)
# * T5 Encoder taken from [Elnagger et al., 2020](https://ieeexplore.ieee.org/document/9477085), [Github](https://github.com/agemagician/ProtTrans), Model on [Huggingface Hub](https://huggingface.co/Rostlab/prot_t5_xl_half_uniref50-enc)

# %%
import os
import sys
import csv
import math
import pickle
import random
import numpy as np
from time import time
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from transformers import T5Tokenizer, T5EncoderModel

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold

# %%
def seed_everything(seed: int):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
seed_everything(1234)

# %%
def read_data(path):
    with open(path, "r") as csvfile:
        train_data = list(csv.reader(csvfile))[1:]  # skip col name
        sents, lbls = [], []
        for s, l in train_data:
            sents.append(s)
            lbls.append(l)
    return sents, lbls


def apply_random_masking(seq, att, num_tokens):
    """
    Mask `num_tokens` as 0 at random positions per sequence.
    """
    dist = torch.rand(seq.shape)
    m, _ = torch.topk(dist, num_tokens)
    return seq * (dist < m), att * (dist < m)


def regularized_auc(train_auc, dev_auc, threshold=0.0025):
    """
    Returns development AUC if overfitting is below threshold, otherwise 0.
    """
    return dev_auc if (train_auc - dev_auc) < threshold else 0


def save_metrics(*args, path):
    if not os.path.isfile(path):
        with open(path, "w", newline="\n") as f:
            f.write(
                ",".join(
                    [
                        "fold",
                        "epoch",
                        "train_loss",
                        "train_acc",
                        "train_auc",
                        "val_loss",
                        "val_acc",
                        "val_auc",
                    ]
                )
            )
            f.write("\n")
    if args:
        with open(path, "a", newline="\n") as f:
            f.write(",".join([str(arg) for arg in args]))
            f.write("\n")


def gelu(x):
    """
    Facebook Research implementation of the gelu activation function.
    
    For information: OpenAI GPT's gelu is slightly different
    (and gives slightly different results):
    0.5 * x * (1 + torch.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * torch.pow(x, 3))))
    """
    return x * 0.5 * (1.0 + torch.erf(x / math.sqrt(2.0)))


def total_model_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def trainable_model_params(model):
    return sum(
        p[1].numel()
        for p in model.named_parameters()
        if p[1].requires_grad and not p[0].startswith("t5")
    )

# %%
class CleavageDataset(Dataset):
    def __init__(self, seq, lbl):
        self.seq = seq
        self.lbl = lbl

    def __getitem__(self, idx):
        return self.seq[idx], self.lbl[idx]

    def __len__(self):
        return len(self.lbl)
    
    
class TrainBatch:
    def __init__(self, batch):
        ordered_batch = list(zip(*batch))
        encoded = tokenizer.batch_encode_plus(
            [seq.replace("", " ").strip() for seq in ordered_batch[0]]
        )
        seq = torch.tensor(encoded["input_ids"], dtype=torch.int64)
        att = torch.tensor(encoded["attention_mask"], dtype=torch.int64)
        self.seq, self.att = apply_random_masking(seq, att, num_tokens=1)
        self.lbl = torch.tensor([int(l) for l in ordered_batch[1]], dtype=torch.float)

    def pin_memory(self):
        self.seq = self.seq.pin_memory()
        self.att = self.att.pin_memory()
        self.lbl = self.lbl.pin_memory()
        return self
    
def train_wrapper(batch):
    return TrainBatch(batch)
    

class EvalBatch:
    def __init__(self, batch):
        ordered_batch = list(zip(*batch))
        encoded = tokenizer.batch_encode_plus(
            [seq.replace("", " ").strip() for seq in ordered_batch[0]]
        )
        self.seq = torch.tensor(encoded["input_ids"], dtype=torch.int64)
        self.att = torch.tensor(encoded["attention_mask"], dtype=torch.int64)
        self.lbl = torch.tensor([int(l) for l in ordered_batch[1]], dtype=torch.float)

    def pin_memory(self):
        self.seq = self.seq.pin_memory()
        self.att = self.att.pin_memory()
        self.lbl = self.lbl.pin_memory()
        return self


def eval_wrapper(batch):
    return EvalBatch(batch)

# %%
class T5_BiLSTM(nn.Module):
    def __init__(self, rnn_size, hidden_size, dropout):
        super().__init__()

        self.t5_encoder = T5EncoderModel.from_pretrained(
            "Rostlab/prot_t5_xl_half_uniref50-enc", torch_dtype=torch.float16
        )

        self.dropout = nn.Dropout(dropout)

        self.lstm = nn.LSTM(
            input_size=self.t5_encoder.config.to_dict()['d_model'], # 1024
            hidden_size=rnn_size,
            bidirectional=True,
            batch_first=True,
        )

        self.fc1 = nn.Linear(rnn_size * 2, hidden_size)
        self.fc2 = nn.Linear(hidden_size, 1)

    def forward(self, seq, att):
        with torch.no_grad():
            # input shape: (batch_size, seq_len=10)
            # out: (batch_size, seq_len+1, embedding_dim=1024)
            embedded = self.dropout(self.t5_encoder(seq, att).last_hidden_state)

        # input shape: (batch_size, seq_len+1, embedding_dim)
        out, _ = self.lstm(embedded)

        # input shape: (batch_size, seq_len=1, 2*rnn_size)
        pooled, _ = torch.max(out, dim=1)

        # input shape: (batch_size, 2*rnn_size)
        out = self.dropout(gelu(self.fc1(pooled)))

        # input shape: (batch_size, hidden_size)
        # output shape: (batch_size)
        return self.fc2(out).squeeze()

# %%
def process(model, loader, criterion, optim=None):
    epoch_loss, num_correct, total = 0, 0, 0
    preds, lbls = [], []
    
    for batch in tqdm(
        loader,
        desc="Train: " if optim is not None else "Eval: ",
        file=sys.stdout,
        unit="batches"
    ):
        seq, att, lbl = batch.seq, batch.att, batch.lbl
        seq, att, lbl = seq.to(device), att.to(device), lbl.to(device)
        
        with torch.cuda.amp.autocast():
            scores = model(seq, att)
            loss = criterion(scores, lbl)
        
        if optim is not None:
            optim.zero_grad()
            scaler.scale(loss).backward()
            scaler.step(optim)
            scaler.update()
        
        epoch_loss += loss.item()
        num_correct += ((scores > 0) == lbl).sum().item()
        total += seq.shape[0]
        preds.extend(scores.detach().tolist())
        lbls.extend(lbl.detach().tolist())
    return epoch_loss / total, num_correct / total, roc_auc_score(lbls, preds)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
BATCH_SIZE = 512

tokenizer = T5Tokenizer.from_pretrained(
    "Rostlab/prot_t5_xl_half_uniref50-enc", do_lower_case=False
)

# load train+dev set, mix it back as one
train_path = '../../data/n_train.csv'
dev_path = '../../data/n_val.csv'
test_path = '../../data/n_test.csv'

# combine previously split train and dev set
train_seqs, train_lbls = read_data(train_path)
dev_seqs, dev_lbls = read_data(dev_path)
total_seqs, total_lbls = np.array(train_seqs + dev_seqs), np.array(train_lbls + dev_lbls)

assert len(train_seqs) + len(dev_seqs) == len(total_seqs)
assert len(train_lbls) + len(dev_lbls) == len(total_lbls)

test_seqs, test_lbls = read_data(test_path)

test_data = CleavageDataset(test_seqs, test_lbls)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, collate_fn=eval_wrapper, pin_memory=True, num_workers=10)

# %%
RNN_SIZE = 512
HIDDEN_SIZE = 128
DROPOUT = 0.5
LEARNING_RATE = 3e-4

params = {
    "rnn_size": RNN_SIZE,
    "hidden_size": HIDDEN_SIZE,
    "dropout": DROPOUT
}

# %%
# scale everything to fp16
scaler = torch.cuda.amp.GradScaler()

NUM_EPOCHS = 10
LEARNING_RATE = 3e-4
criterion = nn.BCEWithLogitsLoss()

kf = KFold(n_splits=5, shuffle=True, random_state=1234)
logging_path = "../../params/n_term/T5_BiLSTM/results.csv"

start = time()
print("Starting Cross-Validation.")
highest_val_auc = 0

# get a new split
for fold, (train_idx, dev_idx) in enumerate(kf.split(total_seqs), 1):
    X_tr = total_seqs[train_idx]
    y_tr = total_lbls[train_idx]
    X_dev = total_seqs[dev_idx]
    y_dev = total_lbls[dev_idx]

    # create datasets and loads with current split
    train_data = CleavageDataset(X_tr, y_tr)
    train_loader = DataLoader(
        train_data,
        batch_size=BATCH_SIZE,
        shuffle=True,
        collate_fn=train_wrapper,
        pin_memory=True,
        num_workers=10,
    )

    dev_data = CleavageDataset(X_dev, y_dev)
    dev_loader = DataLoader(
        dev_data,
        batch_size=BATCH_SIZE,
        shuffle=True,
        collate_fn=eval_wrapper,
        pin_memory=True,
        num_workers=10,
    )

    # reset model weights with each new fold
    if 'model' in globals():
        del model
        print('deleted model')
    model = T5_BiLSTM(**params).to(device)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    # normal training loop
    for epoch in range(1, NUM_EPOCHS + 1):
        model.train()
        train_loss, train_acc, train_auc = process(
            model, train_loader, criterion, optimizer
        )

        model.eval()
        with torch.no_grad():
            val_loss, val_acc, val_auc = process(model, dev_loader, criterion)

        # save metrics
        save_metrics(
            fold,
            epoch,
            train_loss,
            train_acc,
            train_auc,
            val_loss,
            val_acc,
            val_auc,
            path=logging_path,
        )

        print(
            f"Training:   [Fold {fold:2d}, Epoch {epoch:2d}, Loss: {train_loss:8.6f}, Acc: {train_acc:.4f}, AUC: {train_auc:.4f}]"
        )
        print(f"Evaluation: [Fold {fold:2d}, Epoch {epoch:2d}, Loss: {val_loss:8.6f}, Acc: {val_acc:.4f}, AUC: {val_auc:.4f}]")
        
        reg_auc = regularized_auc(train_auc, val_auc, threshold=0)
        if reg_auc > highest_val_auc:
            highest_val_auc = reg_auc
            path = f"../../params/n_term/T5_BiLSTM/auc{reg_auc:.4f}_fold{fold}_epoch{epoch}.pt"
            torch.save(model.state_dict(), path)

print("Finished Cross-Validation.")
train_time = (time() - start) / 60
print(f"Cross-Validation took {train_time} minutes.")
# Out:
# Starting Cross-Validation.
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:45<00:00,  3.13batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:28<00:00,  3.41batches/s]
# Training:   [Fold  1, Epoch  1, Loss: 0.000842, Acc: 0.8211, AUC: 0.7089]
# Evaluation: [Fold  1, Epoch  1, Loss: 0.000784, Acc: 0.8286, AUC: 0.7705]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:31<00:00,  3.20batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:27<00:00,  3.43batches/s]
# Training:   [Fold  1, Epoch  2, Loss: 0.000805, Acc: 0.8252, AUC: 0.7495]
# Evaluation: [Fold  1, Epoch  2, Loss: 0.000770, Acc: 0.8319, AUC: 0.7796]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:31<00:00,  3.20batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:28<00:00,  3.41batches/s]
# Training:   [Fold  1, Epoch  3, Loss: 0.000796, Acc: 0.8265, AUC: 0.7579]
# Evaluation: [Fold  1, Epoch  3, Loss: 0.000764, Acc: 0.8336, AUC: 0.7844]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:32<00:00,  3.19batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:28<00:00,  3.40batches/s]
# Training:   [Fold  1, Epoch  4, Loss: 0.000790, Acc: 0.8278, AUC: 0.7631]
# Evaluation: [Fold  1, Epoch  4, Loss: 0.000763, Acc: 0.8334, AUC: 0.7869]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:30<00:00,  3.20batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:27<00:00,  3.43batches/s]
# Training:   [Fold  1, Epoch  5, Loss: 0.000786, Acc: 0.8281, AUC: 0.7663]
# Evaluation: [Fold  1, Epoch  5, Loss: 0.000758, Acc: 0.8344, AUC: 0.7882]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:30<00:00,  3.20batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:28<00:00,  3.41batches/s]
# Training:   [Fold  1, Epoch  6, Loss: 0.000783, Acc: 0.8287, AUC: 0.7692]
# Evaluation: [Fold  1, Epoch  6, Loss: 0.000757, Acc: 0.8342, AUC: 0.7898]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:37<00:00,  3.17batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:32<00:00,  3.31batches/s]
# Training:   [Fold  1, Epoch  7, Loss: 0.000781, Acc: 0.8294, AUC: 0.7706]
# Evaluation: [Fold  1, Epoch  7, Loss: 0.000756, Acc: 0.8347, AUC: 0.7902]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:33<00:00,  3.19batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:27<00:00,  3.42batches/s]
# Training:   [Fold  1, Epoch  8, Loss: 0.000779, Acc: 0.8296, AUC: 0.7722]
# Evaluation: [Fold  1, Epoch  8, Loss: 0.000756, Acc: 0.8340, AUC: 0.7909]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:32<00:00,  3.19batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:27<00:00,  3.42batches/s]
# Training:   [Fold  1, Epoch  9, Loss: 0.000776, Acc: 0.8301, AUC: 0.7745]
# Evaluation: [Fold  1, Epoch  9, Loss: 0.000756, Acc: 0.8335, AUC: 0.7918]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:31<00:00,  3.20batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:27<00:00,  3.42batches/s]
# Training:   [Fold  1, Epoch 10, Loss: 0.000775, Acc: 0.8305, AUC: 0.7756]
# Evaluation: [Fold  1, Epoch 10, Loss: 0.000753, Acc: 0.8353, AUC: 0.7921]
# deleted model
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:33<00:00,  3.18batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:27<00:00,  3.42batches/s]
# Training:   [Fold  2, Epoch  1, Loss: 0.000844, Acc: 0.8205, AUC: 0.7062]
# Evaluation: [Fold  2, Epoch  1, Loss: 0.000786, Acc: 0.8269, AUC: 0.7708]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:27<00:00,  3.21batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:27<00:00,  3.43batches/s]
# Training:   [Fold  2, Epoch  2, Loss: 0.000808, Acc: 0.8248, AUC: 0.7458]
# Evaluation: [Fold  2, Epoch  2, Loss: 0.000773, Acc: 0.8296, AUC: 0.7793]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:25<00:00,  3.22batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  2, Epoch  3, Loss: 0.000798, Acc: 0.8266, AUC: 0.7552]
# Evaluation: [Fold  2, Epoch  3, Loss: 0.000769, Acc: 0.8304, AUC: 0.7834]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:13<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  2, Epoch  4, Loss: 0.000793, Acc: 0.8272, AUC: 0.7594]
# Evaluation: [Fold  2, Epoch  4, Loss: 0.000765, Acc: 0.8321, AUC: 0.7864]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:13<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  2, Epoch  5, Loss: 0.000789, Acc: 0.8282, AUC: 0.7631]
# Evaluation: [Fold  2, Epoch  5, Loss: 0.000765, Acc: 0.8326, AUC: 0.7885]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:13<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  2, Epoch  6, Loss: 0.000786, Acc: 0.8286, AUC: 0.7656]
# Evaluation: [Fold  2, Epoch  6, Loss: 0.000759, Acc: 0.8323, AUC: 0.7898]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:13<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  2, Epoch  7, Loss: 0.000784, Acc: 0.8292, AUC: 0.7674]
# Evaluation: [Fold  2, Epoch  7, Loss: 0.000759, Acc: 0.8326, AUC: 0.7904]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:13<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  2, Epoch  8, Loss: 0.000782, Acc: 0.8294, AUC: 0.7691]
# Evaluation: [Fold  2, Epoch  8, Loss: 0.000758, Acc: 0.8329, AUC: 0.7911]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:13<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  2, Epoch  9, Loss: 0.000780, Acc: 0.8296, AUC: 0.7706]
# Evaluation: [Fold  2, Epoch  9, Loss: 0.000757, Acc: 0.8336, AUC: 0.7921]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:13<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  2, Epoch 10, Loss: 0.000778, Acc: 0.8302, AUC: 0.7719]
# Evaluation: [Fold  2, Epoch 10, Loss: 0.000755, Acc: 0.8338, AUC: 0.7928]
# deleted model
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:15<00:00,  3.28batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  3, Epoch  1, Loss: 0.000842, Acc: 0.8208, AUC: 0.7073]
# Evaluation: [Fold  3, Epoch  1, Loss: 0.000786, Acc: 0.8280, AUC: 0.7733]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:12<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  3, Epoch  2, Loss: 0.000805, Acc: 0.8254, AUC: 0.7480]
# Evaluation: [Fold  3, Epoch  2, Loss: 0.000777, Acc: 0.8301, AUC: 0.7808]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:12<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  3, Epoch  3, Loss: 0.000795, Acc: 0.8272, AUC: 0.7571]
# Evaluation: [Fold  3, Epoch  3, Loss: 0.000768, Acc: 0.8309, AUC: 0.7859]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:12<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  3, Epoch  4, Loss: 0.000789, Acc: 0.8280, AUC: 0.7623]
# Evaluation: [Fold  3, Epoch  4, Loss: 0.000764, Acc: 0.8325, AUC: 0.7883]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:12<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  3, Epoch  5, Loss: 0.000785, Acc: 0.8290, AUC: 0.7660]
# Evaluation: [Fold  3, Epoch  5, Loss: 0.000762, Acc: 0.8326, AUC: 0.7901]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:12<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  3, Epoch  6, Loss: 0.000782, Acc: 0.8293, AUC: 0.7683]
# Evaluation: [Fold  3, Epoch  6, Loss: 0.000760, Acc: 0.8331, AUC: 0.7914]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:12<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  3, Epoch  7, Loss: 0.000780, Acc: 0.8298, AUC: 0.7699]
# Evaluation: [Fold  3, Epoch  7, Loss: 0.000758, Acc: 0.8334, AUC: 0.7925]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:12<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  3, Epoch  8, Loss: 0.000778, Acc: 0.8302, AUC: 0.7722]
# Evaluation: [Fold  3, Epoch  8, Loss: 0.000758, Acc: 0.8331, AUC: 0.7928]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:13<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  3, Epoch  9, Loss: 0.000776, Acc: 0.8306, AUC: 0.7737]
# Evaluation: [Fold  3, Epoch  9, Loss: 0.000757, Acc: 0.8331, AUC: 0.7940]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:13<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:23<00:00,  3.51batches/s]
# Training:   [Fold  3, Epoch 10, Loss: 0.000774, Acc: 0.8309, AUC: 0.7752]
# Evaluation: [Fold  3, Epoch 10, Loss: 0.000756, Acc: 0.8336, AUC: 0.7942]
# deleted model
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:16<00:00,  3.27batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  4, Epoch  1, Loss: 0.000845, Acc: 0.8198, AUC: 0.7063]
# Evaluation: [Fold  4, Epoch  1, Loss: 0.000783, Acc: 0.8290, AUC: 0.7688]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.28batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  4, Epoch  2, Loss: 0.000808, Acc: 0.8245, AUC: 0.7464]
# Evaluation: [Fold  4, Epoch  2, Loss: 0.000772, Acc: 0.8313, AUC: 0.7776]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.28batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  4, Epoch  3, Loss: 0.000798, Acc: 0.8263, AUC: 0.7560]
# Evaluation: [Fold  4, Epoch  3, Loss: 0.000766, Acc: 0.8330, AUC: 0.7821]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:13<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  4, Epoch  4, Loss: 0.000793, Acc: 0.8270, AUC: 0.7604]
# Evaluation: [Fold  4, Epoch  4, Loss: 0.000762, Acc: 0.8333, AUC: 0.7850]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:13<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.51batches/s]
# Training:   [Fold  4, Epoch  5, Loss: 0.000789, Acc: 0.8277, AUC: 0.7638]
# Evaluation: [Fold  4, Epoch  5, Loss: 0.000760, Acc: 0.8335, AUC: 0.7868]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  4, Epoch  6, Loss: 0.000786, Acc: 0.8280, AUC: 0.7661]
# Evaluation: [Fold  4, Epoch  6, Loss: 0.000758, Acc: 0.8341, AUC: 0.7884]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  4, Epoch  7, Loss: 0.000784, Acc: 0.8290, AUC: 0.7682]
# Evaluation: [Fold  4, Epoch  7, Loss: 0.000760, Acc: 0.8328, AUC: 0.7883]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  4, Epoch  8, Loss: 0.000782, Acc: 0.8292, AUC: 0.7694]
# Evaluation: [Fold  4, Epoch  8, Loss: 0.000756, Acc: 0.8345, AUC: 0.7899]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  4, Epoch  9, Loss: 0.000781, Acc: 0.8290, AUC: 0.7707]
# Evaluation: [Fold  4, Epoch  9, Loss: 0.000756, Acc: 0.8338, AUC: 0.7909]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  4, Epoch 10, Loss: 0.000779, Acc: 0.8296, AUC: 0.7722]
# Evaluation: [Fold  4, Epoch 10, Loss: 0.000761, Acc: 0.8324, AUC: 0.7912]
# deleted model
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:16<00:00,  3.27batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  5, Epoch  1, Loss: 0.000844, Acc: 0.8196, AUC: 0.7072]
# Evaluation: [Fold  5, Epoch  1, Loss: 0.000781, Acc: 0.8299, AUC: 0.7710]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.28batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  5, Epoch  2, Loss: 0.000807, Acc: 0.8248, AUC: 0.7477]
# Evaluation: [Fold  5, Epoch  2, Loss: 0.000769, Acc: 0.8319, AUC: 0.7798]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.28batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  5, Epoch  3, Loss: 0.000796, Acc: 0.8268, AUC: 0.7574]
# Evaluation: [Fold  5, Epoch  3, Loss: 0.000762, Acc: 0.8333, AUC: 0.7846]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.28batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  5, Epoch  4, Loss: 0.000791, Acc: 0.8274, AUC: 0.7621]
# Evaluation: [Fold  5, Epoch  4, Loss: 0.000761, Acc: 0.8332, AUC: 0.7863]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.28batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  5, Epoch  5, Loss: 0.000787, Acc: 0.8281, AUC: 0.7657]
# Evaluation: [Fold  5, Epoch  5, Loss: 0.000757, Acc: 0.8347, AUC: 0.7886]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.29batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  5, Epoch  6, Loss: 0.000784, Acc: 0.8288, AUC: 0.7684]
# Evaluation: [Fold  5, Epoch  6, Loss: 0.000758, Acc: 0.8334, AUC: 0.7892]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.28batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  5, Epoch  7, Loss: 0.000782, Acc: 0.8292, AUC: 0.7703]
# Evaluation: [Fold  5, Epoch  7, Loss: 0.000756, Acc: 0.8344, AUC: 0.7902]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.28batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.51batches/s]
# Training:   [Fold  5, Epoch  8, Loss: 0.000779, Acc: 0.8295, AUC: 0.7724]
# Evaluation: [Fold  5, Epoch  8, Loss: 0.000754, Acc: 0.8349, AUC: 0.7914]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.28batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  5, Epoch  9, Loss: 0.000777, Acc: 0.8301, AUC: 0.7739]
# Evaluation: [Fold  5, Epoch  9, Loss: 0.000753, Acc: 0.8351, AUC: 0.7917]
# Train: 100%|████████████████████████████████████████████████████| 2018/2018 [10:14<00:00,  3.28batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 505/505 [02:24<00:00,  3.50batches/s]
# Training:   [Fold  5, Epoch 10, Loss: 0.000776, Acc: 0.8302, AUC: 0.7753]
# Evaluation: [Fold  5, Epoch 10, Loss: 0.000753, Acc: 0.8347, AUC: 0.7926]
# Finished Cross-Validation.
# Cross-Validation took 640.7763087709744 minutes.

# %%
if 'model' in globals():
    del model
    print('deleted model')

model = T5_BiLSTM(**params).to('cpu')
criterion = nn.BCEWithLogitsLoss()

# load best model, evaluate on test set
best_model = sorted(
    [f for f in os.listdir("../../params/n_term/T5_BiLSTM/") if f.endswith(".pt")],
    reverse=True,
)[0]
print("Loaded model: ", best_model)
checkpoint = torch.load('../../params/n_term/T5_BiLSTM/' + best_model, map_location='cpu')
model.load_state_dict(checkpoint)
model = model.to(device)
model.eval()

with torch.no_grad():
    test_loss, test_acc, test_auc = process(model, test_loader, criterion)
print(
    f"Test Set Performance: Loss: {test_loss:.6f}, Acc: {test_acc:.4f}, AUC: {test_auc:.4f}"
)

print(
    f"Total model params: {total_model_params(model)}, trainable model params: {trainable_model_params(model)}"
)
# Out:
# deleted model
# Loaded model:  auc0.7942_fold3_epoch10.pt
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [01:20<00:00,  3.48batches/s]
# Test Set Performance: Loss: 0.000752, Acc: 0.8345, AUC: 0.7948
# Total model params: 1214572801, trainable model params: 6430977
