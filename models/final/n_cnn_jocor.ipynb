# %% [markdown]
# # Sources
# * Model architecture based on [Li et al., 2020](https://academic.oup.com/bioinformatics/article/36/4/1057/5578482?login=true), Repository available via download section on [Homepage](https://deepcleave.erc.monash.edu/)
# * JoCoR loss function and training process adaptations are based on [Wei et al., 2020](https://openaccess.thecvf.com/content_CVPR_2020/html/Wei_Combating_Noisy_Labels_by_Agreement_A_Joint_Training_Method_with_CVPR_2020_paper.html), and official implementation on [Github](https://github.com/hongxin001/JoCoR)

# %%
import os
import sys
import csv
import random
import math
import numpy as np
from time import time
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from torchtext.vocab import build_vocab_from_iterator

from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
def seed_everything(seed: int):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
seed_everything(1234)

# %%
def read_data(path):
    with open(path, "r") as csvfile:
        train_data = list(csv.reader(csvfile))[1:]  # skip col name
        sents, lbls = [], []
        for s, l in train_data:
            sents.append(s)
            lbls.append(l)
    return sents, lbls


def apply_random_masking(seq, num_tokens):
    """
    Mask `num_tokens` as 0 at random positions per sequence.
    """
    dist = torch.rand(seq.shape)
    m, _ = torch.topk(dist, num_tokens)
    return seq * (dist < m)


def regularized_auc(train_auc, dev_auc, threshold=0.0025):
    """
    Returns development AUC if overfitting is below threshold, otherwise 0.
    """
    return dev_auc if (train_auc - dev_auc) < threshold else 0


def gelu(x):
    """
    Facebook Research implementation of the gelu activation function.
    
    For information: OpenAI GPT's gelu is slightly different
    (and gives slightly different results):
    0.5 * x * (1 + torch.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * torch.pow(x, 3))))
    """
    return x * 0.5 * (1.0 + torch.erf(x / math.sqrt(2.0)))


def trainable_model_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def total_model_params(model):
    return sum(p.numel() for p in model.parameters())

# %%
class CleavageDataset(Dataset):
    def __init__(self, seq, lbl):
        self.seq = seq
        self.lbl = lbl
    
    def __getitem__(self, idx):
        return self.seq[idx], self.lbl[idx]
    
    def __len__(self):
        return len(self.lbl)
    
class TrainBatch:
    def __init__(self, batch):
        ordered_batch = list(zip(*batch))
        seq = torch.tensor([encode_text(seq) for seq in ordered_batch[0]], dtype=torch.float)
        self.seq = apply_random_masking(seq, num_tokens=1)
        self.lbl = torch.tensor([int(l) for l in ordered_batch[1]], dtype=torch.float)
        
    def pin_memory(self):
        self.seq = self.seq.pin_memory()
        self.lbl = self.lbl.pin_memory()
        return self
    
def train_wrapper(batch):
    return TrainBatch(batch)


class EvalBatch:
    def __init__(self, batch):
        ordered_batch = list(zip(*batch))
        self.seq = torch.tensor([encode_text(seq) for seq in ordered_batch[0]], dtype=torch.float)
        self.lbl = torch.tensor([int(l) for l in ordered_batch[1]], dtype=torch.float)
        
    def pin_memory(self):
        self.seq = self.seq.pin_memory()
        self.lbl = self.lbl.pin_memory()
        return self
    
def eval_wrapper(batch):
    return EvalBatch(batch)

# %%
class Attention(nn.Module):
    def __init__(self, input_dim, hidden):
        super().__init__()

        self.W0 = nn.Parameter(
            nn.init.kaiming_normal_(torch.empty(input_dim, hidden)).to(device)
        )
        self.W = nn.Parameter(
            nn.init.kaiming_normal_(torch.empty(hidden, 1)).to(device)
        )
        self.b0 = nn.Parameter(
            nn.init.kaiming_normal_(torch.empty(hidden, 1)).squeeze().to(device)
        )
        self.b = nn.Parameter(
            nn.init.kaiming_normal_(torch.empty(1, 1)).squeeze(1).to(device)
        )

    def forward(self, x):
        # input shape: (batch_size, num_filters, seq_len)
        # input needs to be permuted
        energy = (
            x.permute(0, 2, 1) @ self.W0 + self.b0
        )  # linear activation, i.e. only identity

        # input shape: (batch_size, seq_len, hidden)
        energy = (energy @ self.W + self.b).squeeze()

        # input shape: (batch_size, seq_len)
        energy = F.softmax(energy, dim=1)

        # input shape: energy=(batch_size, seq_len)
        # output shape: (batch_size, input_dim)
        # batch-wise dot product along dims 1
        res = (energy.unsqueeze(1) @ x.permute(0, 2, 1)).squeeze(1)

        # input shape: (batch_size, input_dim)
        # output shape: (batch_size, input_dim+seq_len)
        return torch.concat([res, energy], axis=-1)

# %%
class CNNAttention(nn.Module):
    def __init__(
        self,
        seq_len,
        num_filters1,
        kernel_size1,
        num_filters2,
        kernel_size2a,
        kernel_size2b,
        kernel_size2c,
        num_filters3,
        kernel_size3a,
        kernel_size3b,
        kernel_size3c,
        attention_hidden1,
        attention_hidden2,
        hidden_size1,
        hidden_size2,
        dropout
    ):
        super().__init__()

        self.dropout = nn.Dropout(dropout)

        self.conv1 = nn.Conv1d(
            in_channels=1,
            out_channels=num_filters1,
            kernel_size=kernel_size1,
            padding="same",
        )

        self.conv2a = nn.Conv1d(
            in_channels=num_filters1,
            out_channels=num_filters2,
            kernel_size=kernel_size2a,
            padding="same",
        )

        self.conv2b = nn.Conv1d(
            in_channels=num_filters1,
            out_channels=num_filters2,
            kernel_size=kernel_size2b,
            padding="same",
        )

        self.conv2c = nn.Conv1d(
            in_channels=num_filters1,
            out_channels=num_filters2,
            kernel_size=kernel_size2c,
            padding="same",
        )

        self.conv3a = nn.Conv1d(
            in_channels=3 * num_filters2,
            out_channels=num_filters3,
            kernel_size=kernel_size3a,
            padding="same",
        )

        self.conv3b = nn.Conv1d(
            in_channels=3 * num_filters2,
            out_channels=num_filters3,
            kernel_size=kernel_size3b,
            padding="same",
        )

        self.conv3c = nn.Conv1d(
            in_channels=3 * num_filters2,
            out_channels=num_filters3,
            kernel_size=kernel_size3c,
            padding="same",
        )

        self.attention1 = Attention(input_dim=num_filters3, hidden=attention_hidden1)
        self.attention1r = Attention(input_dim=seq_len, hidden=attention_hidden2)

        self.attention2 = Attention(input_dim=num_filters3, hidden=attention_hidden1)
        self.attention2r = Attention(input_dim=seq_len, hidden=attention_hidden2)

        self.attention3 = Attention(input_dim=num_filters3, hidden=attention_hidden1)
        self.attention3r = Attention(input_dim=seq_len, hidden=attention_hidden2)

        self.fc1 = nn.Linear(3*num_filters3 + 3*seq_len, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, 1)

    def forward(self, seq):
        ### encoder ###

        # in: (batch_size, seq_len), out: (batch_size, num_filters1, seq_len)
        x1 = F.leaky_relu(self.dropout(self.conv1(seq.unsqueeze(1))))  # add dim=1 for conv

        # in: (batch_size, num_filters1, seq_len)
        # out: (batch_size, num_filters2, seq_len)
        y1 = F.leaky_relu(self.dropout(self.conv2a(x1)))
        y2 = F.leaky_relu(self.dropout(self.conv2b(x1)))
        y3 = F.leaky_relu(self.dropout(self.conv2c(x1)))
        # cat_y out: (batch_size, 3*num_filters2, seq_len)
        cat_y = self.dropout(torch.cat([y1, y2, y3], dim=1))

        # in: (batch_size, 3*num_filters2, seq_len)
        # out: (batch_size, num_filters3, seq_len)
        z1 = self.dropout(F.leaky_relu(self.conv3a(cat_y)))
        z2 = self.dropout(F.leaky_relu(self.conv3b(cat_y)))
        z3 = self.dropout(F.leaky_relu(self.conv3c(cat_y)))

        ### decoder ###

        # in: (batch_size, num_filters3, seq_len)
        # out w/out r, e.g. decoded_z1: (batch_size, num_filters3)
        # out w/ r: e.g. decoded_z1r: (batch_size, seq_len)
        decoded_z1 = self.attention1(z1)[:, : z1.shape[1]]
        decoded_z1r = self.attention1r(z1.permute(0, 2, 1))[:, : z1.shape[2]]

        decoded_z2 = self.attention2(z2)[:, : z2.shape[1]]
        decoded_z2r = self.attention2r(z2.permute(0, 2, 1))[:, : z2.shape[2]]

        decoded_z3 = self.attention3(z3)[:, : z3.shape[1]]
        decoded_z3r = self.attention3r(z3.permute(0, 2, 1))[:, : z3.shape[2]]

        # out: (batch_size, 3*num_filters3 + 3*seq_len)
        cat = self.dropout(
            torch.cat(
                [
                    decoded_z1,
                    decoded_z1r,
                    decoded_z2,
                    decoded_z2r,
                    decoded_z3,
                    decoded_z3r,
                ],
                dim=-1,
            )
        )

        # in: (batch_size, 3*num_filters3 + 3*seq_len), out: (batch_size, hidden_size1)
        out = self.dropout(F.leaky_relu(self.fc1(cat)))
        # in: (batch_size, hidden_size1), out: (batch_size, hidden_size2)
        out = self.dropout(F.leaky_relu(self.fc2(out)))
        # in: (batch_size, hidden_size2), out: (batch_size, 1)
        return self.fc3(out).squeeze()

# %%
def kl_loss_compute(pred, soft_targets):
    # adjusted for binary case
    kl = F.kl_div(F.logsigmoid(pred), torch.sigmoid(soft_targets), reduction='none')
    return torch.sum(kl)


class JoCoRLoss:
    def __call__(self, y1, y2, lbls, forget_rate, loss_func, kl_loss, co_lambda=0.1):
        loss_pick_1 = loss_func(y1, lbls) * (1 - co_lambda)
        loss_pick_2 = loss_func(y2, lbls) * (1 - co_lambda)
        loss_pick = (
            loss_pick_1
            + loss_pick_2
            + co_lambda * kl_loss_compute(y1, y2)
            + co_lambda * kl_loss_compute(y2, y1)
        ).cpu()

        ind_sorted = np.argsort(loss_pick.data)
        loss_sorted = loss_pick[ind_sorted]

        remember_rate = 1 - forget_rate
        num_remember = int(remember_rate * len(loss_sorted))

        ind_update = ind_sorted[:num_remember]

        loss = torch.mean(loss_pick[ind_update])

        return loss, loss

# %%
def train(model1, model2, optim, loss_func, loader, forget_rate, BCEWLL, kl_loss):
    epoch_loss1, num_correct1, total = 0, 0, 0
    epoch_loss2, num_correct2 = 0, 0
    preds1, preds2, lbls = [], [], []
    
    for batch in tqdm(loader, desc="Train: ", file=sys.stdout, unit="batches"):
        seq, lbl = batch.seq, batch.lbl
        seq, lbl = seq.to(device), lbl.to(device)
        
        scores1 = model1(seq)
        scores2 = model2(seq)

        # JoCoR loss
        loss1, loss2 = loss_func(scores1, scores2, lbl, forget_rate, BCEWLL, kl_loss)
        
        optim.zero_grad()
        loss1.backward()
        optim.step()
        
        epoch_loss1 += loss1.item()
        epoch_loss2 += loss2.item()
        num_correct1 += ((scores1 > 0) == lbl).sum().item()
        num_correct2 += ((scores2 > 0) == lbl).sum().item()
        total += seq.shape[0]
        preds1.extend(scores1.detach().tolist())
        preds2.extend(scores2.detach().tolist())
        lbls.extend(lbl.detach().tolist())
        
    return (
        epoch_loss1 / total,
        epoch_loss2 / total,
        num_correct1 / total,
        num_correct2 / total,
        roc_auc_score(lbls, preds1),
        roc_auc_score(lbls, preds2)
    )

# %%
def evaluate(model1, model2, loader):
    num_correct1, num_correct2, total = 0, 0, 0
    preds1, preds2, lbls = [], [], []
    
    for batch in tqdm(loader, desc="Eval: ", file=sys.stdout, unit="batches"):
        seq, lbl = batch.seq, batch.lbl
        seq, lbl = seq.to(device), lbl.to(device)
        
        scores1 = model1(seq)
        scores2 = model2(seq)
        
        num_correct1 += ((scores1 > 0) == lbl).sum().item()
        num_correct2 += ((scores2 > 0) == lbl).sum().item()
        total += seq.shape[0]
        preds1.extend(scores1.detach().tolist())
        preds2.extend(scores2.detach().tolist())
        lbls.extend(lbl.detach().tolist())
        
    return (
        num_correct1 / total,
        num_correct2 / total,
        roc_auc_score(lbls, preds1),
        roc_auc_score(lbls, preds2)
    )

# %%
def test(model, loader):
    num_correct, total = 0, 0
    preds, lbls = [], []
    
    for batch in tqdm(loader, desc="Eval: ", file=sys.stdout, unit="batches"):
        seq, lbl = batch.seq, batch.lbl
        seq, lbl = seq.to(device), lbl.to(device)
        
        scores = model(seq)
        
        num_correct += ((scores > 0) == lbl).sum().item()
        total += seq.shape[0]
        preds.extend(scores.detach().tolist())
        lbls.extend(lbl.detach().tolist())
        
    return num_correct / total, roc_auc_score(lbls, preds)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# load train and dev data
train_seqs, train_lbl = read_data('../../data/n_train.csv')
dev_seqs, dev_lbl = read_data('../../data/n_val.csv')

# create vocab from train seqs
vocab = build_vocab_from_iterator(train_seqs, specials=['<UNK>'])
vocab.set_default_index(vocab['<UNK>'])
encode_text = lambda x: vocab(list(x))

# %%
NUM_EPOCHS = 60
BATCH_SIZE = 512
VOCAB_SIZE = len(vocab)
LEARNING_RATE = 3e-4

NUM_GRADUAL = 10 # how many epochs for linear drop rate
NOISY_RATE = 0.2 # assumed
FORGET_RATE = NOISY_RATE / 2 # recommendation when facing asymmetric loss
EXPONENT = 1

# define drop rate schedule
rate_schedule = np.ones(NUM_EPOCHS)*FORGET_RATE
rate_schedule[:NUM_GRADUAL] = np.linspace(0, FORGET_RATE**EXPONENT, NUM_GRADUAL)

params = {
    'seq_len': 10,
    'kernel_size1': 1,
    'kernel_size2a': 1,
    'kernel_size2b': 15,
    'kernel_size2c': 13,
    'kernel_size3a': 13,
    'kernel_size3b': 21,
    'kernel_size3c': 15,
    'num_filters1': 249,
    'num_filters2': 229,
    'num_filters3': 400,
    'attention_hidden1': 4,
    'attention_hidden2': 3,
    'hidden_size1': 89,
    'hidden_size2': 15,
    'dropout': 0.08,
}

model1 = CNNAttention(**params).to(device)
model2 = CNNAttention(**params).to(device)

BCEWLL = nn.BCEWithLogitsLoss(reduction='none')
criterion = JoCoRLoss()
optimizer = optim.Adam(list(model1.parameters()) + list(model2.parameters()), lr=LEARNING_RATE)

# create train and dev loader
train_data = CleavageDataset(train_seqs, train_lbl)
train_loader = DataLoader(train_data, batch_size = BATCH_SIZE, shuffle=True, collate_fn=train_wrapper, pin_memory=True, num_workers=10)

dev_data = CleavageDataset(dev_seqs, dev_lbl)
dev_loader = DataLoader(dev_data, batch_size = BATCH_SIZE, shuffle=True, collate_fn=eval_wrapper, pin_memory=True, num_workers=10)

# %%
start = time()
print("Starting Training.")
highest_val_auc = 0

# normal training loop
for epoch in range(1, NUM_EPOCHS + 1):
    model1.train()
    model2.train()
    train_loss1, train_loss2, train_acc1, train_acc2, train_auc1, train_auc2 = train(
        model1=model1,
        model2=model2,
        optim=optimizer,
        loss_func=criterion, # JoCoRLoss
        loader=train_loader,
        forget_rate=rate_schedule[epoch-1],
        BCEWLL=BCEWLL, # nn.BCEWithLogitsLoss with reduction=none
        kl_loss=kl_loss_compute
    )

    model1.eval()
    model2.eval()
    with torch.no_grad():
        val_acc1, val_acc2, val_auc1, val_auc2 = evaluate(
            model1=model1,
            model2=model2,
            loader=dev_loader,
        )
    
    print(
        f"Model 1 Training:   [Epoch {epoch:2d}, Loss: {train_loss1:8.6f}, Acc: {train_acc1:.4f}, AUC: {train_auc1:.4f}]"
    )
    print(
        f"Model 1 Evaluation: [Epoch {epoch:2d}, Acc: {val_acc1:.4f}, AUC: {val_auc1:.4f}]"
    )
    print(
        f"Model 2 Training:   [Epoch {epoch:2d}, Loss: {train_loss2:8.6f}, Acc: {train_acc2:.4f}, AUC: {train_auc2:.4f}]"
    )
    print(
        f"Model 2 Evaluation: [Epoch {epoch:2d}, Acc: {val_acc2:.4f}, AUC: {val_auc2:.4f}]"
    )

    if val_auc1 > val_auc2:
        reg_auc = regularized_auc(train_auc1, val_auc1, threshold=0)
        model = model1.state_dict()
        print('saved model1')
    else:
        reg_auc = regularized_auc(train_auc2, val_auc2, threshold=0)
        model = model2.state_dict()
        print('saved model2')
    if reg_auc > highest_val_auc:
        highest_val_auc = reg_auc
        path = f"../../params/n_term/cnnAttention_jocor/auc{reg_auc:.4f}_epoch{epoch}.pt"
        torch.save(model, path)

print("Finished Training.")
train_time = (time() - start) / 60
print(f"Training took {train_time} minutes.")
# Out:
# Starting Training.
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:41<00:00, 22.05batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 76.24batches/s]
# Model 1 Training:   [Epoch  1, Loss: 0.002122, Acc: 0.8178, AUC: 0.5175]
# Model 1 Evaluation: [Epoch  1, Acc: 0.8179, AUC: 0.5510]
# Model 2 Training:   [Epoch  1, Loss: 0.002122, Acc: 0.8157, AUC: 0.5173]
# Model 2 Evaluation: [Epoch  1, Acc: 0.8179, AUC: 0.5490]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.68batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.69batches/s]
# Model 1 Training:   [Epoch  2, Loss: 0.001860, Acc: 0.8183, AUC: 0.5567]
# Model 1 Evaluation: [Epoch  2, Acc: 0.8179, AUC: 0.5769]
# Model 2 Training:   [Epoch  2, Loss: 0.001860, Acc: 0.8183, AUC: 0.5533]
# Model 2 Evaluation: [Epoch  2, Acc: 0.8179, AUC: 0.5759]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.75batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.24batches/s]
# Model 1 Training:   [Epoch  3, Loss: 0.001724, Acc: 0.8183, AUC: 0.5717]
# Model 1 Evaluation: [Epoch  3, Acc: 0.8179, AUC: 0.5831]
# Model 2 Training:   [Epoch  3, Loss: 0.001724, Acc: 0.8183, AUC: 0.5701]
# Model 2 Evaluation: [Epoch  3, Acc: 0.8179, AUC: 0.5836]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.71batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.01batches/s]
# Model 1 Training:   [Epoch  4, Loss: 0.001604, Acc: 0.8183, AUC: 0.5751]
# Model 1 Evaluation: [Epoch  4, Acc: 0.8179, AUC: 0.5858]
# Model 2 Training:   [Epoch  4, Loss: 0.001604, Acc: 0.8183, AUC: 0.5745]
# Model 2 Evaluation: [Epoch  4, Acc: 0.8179, AUC: 0.5869]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.73batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.88batches/s]
# Model 1 Training:   [Epoch  5, Loss: 0.001505, Acc: 0.8183, AUC: 0.5720]
# Model 1 Evaluation: [Epoch  5, Acc: 0.8179, AUC: 0.5817]
# Model 2 Training:   [Epoch  5, Loss: 0.001505, Acc: 0.8183, AUC: 0.5709]
# Model 2 Evaluation: [Epoch  5, Acc: 0.8179, AUC: 0.5806]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.83batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.65batches/s]
# Model 1 Training:   [Epoch  6, Loss: 0.001399, Acc: 0.8183, AUC: 0.5665]
# Model 1 Evaluation: [Epoch  6, Acc: 0.8179, AUC: 0.5749]
# Model 2 Training:   [Epoch  6, Loss: 0.001399, Acc: 0.8183, AUC: 0.5663]
# Model 2 Evaluation: [Epoch  6, Acc: 0.8179, AUC: 0.5749]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.77batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.10batches/s]
# Model 1 Training:   [Epoch  7, Loss: 0.001239, Acc: 0.8183, AUC: 0.5650]
# Model 1 Evaluation: [Epoch  7, Acc: 0.8179, AUC: 0.5748]
# Model 2 Training:   [Epoch  7, Loss: 0.001239, Acc: 0.8183, AUC: 0.5649]
# Model 2 Evaluation: [Epoch  7, Acc: 0.8179, AUC: 0.5741]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:39<00:00, 22.65batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.40batches/s]
# Model 1 Training:   [Epoch  8, Loss: 0.001112, Acc: 0.8183, AUC: 0.5654]
# Model 1 Evaluation: [Epoch  8, Acc: 0.8179, AUC: 0.5737]
# Model 2 Training:   [Epoch  8, Loss: 0.001112, Acc: 0.8183, AUC: 0.5653]
# Model 2 Evaluation: [Epoch  8, Acc: 0.8179, AUC: 0.5736]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.72batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.66batches/s]
# Model 1 Training:   [Epoch  9, Loss: 0.000985, Acc: 0.8183, AUC: 0.5645]
# Model 1 Evaluation: [Epoch  9, Acc: 0.8179, AUC: 0.5730]
# Model 2 Training:   [Epoch  9, Loss: 0.000985, Acc: 0.8183, AUC: 0.5643]
# Model 2 Evaluation: [Epoch  9, Acc: 0.8179, AUC: 0.5722]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.80batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 77.95batches/s]
# Model 1 Training:   [Epoch 10, Loss: 0.000858, Acc: 0.8183, AUC: 0.5613]
# Model 1 Evaluation: [Epoch 10, Acc: 0.8179, AUC: 0.5670]
# Model 2 Training:   [Epoch 10, Loss: 0.000858, Acc: 0.8183, AUC: 0.5618]
# Model 2 Evaluation: [Epoch 10, Acc: 0.8179, AUC: 0.5676]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:39<00:00, 22.64batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 77.97batches/s]
# Model 1 Training:   [Epoch 11, Loss: 0.000835, Acc: 0.8183, AUC: 0.5645]
# Model 1 Evaluation: [Epoch 11, Acc: 0.8179, AUC: 0.5709]
# Model 2 Training:   [Epoch 11, Loss: 0.000835, Acc: 0.8183, AUC: 0.5648]
# Model 2 Evaluation: [Epoch 11, Acc: 0.8179, AUC: 0.5712]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.67batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.69batches/s]
# Model 1 Training:   [Epoch 12, Loss: 0.000834, Acc: 0.8183, AUC: 0.5687]
# Model 1 Evaluation: [Epoch 12, Acc: 0.8179, AUC: 0.5767]
# Model 2 Training:   [Epoch 12, Loss: 0.000834, Acc: 0.8183, AUC: 0.5689]
# Model 2 Evaluation: [Epoch 12, Acc: 0.8179, AUC: 0.5763]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:37<00:00, 22.91batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.31batches/s]
# Model 1 Training:   [Epoch 13, Loss: 0.000829, Acc: 0.8183, AUC: 0.5734]
# Model 1 Evaluation: [Epoch 13, Acc: 0.8179, AUC: 0.5813]
# Model 2 Training:   [Epoch 13, Loss: 0.000829, Acc: 0.8183, AUC: 0.5738]
# Model 2 Evaluation: [Epoch 13, Acc: 0.8179, AUC: 0.5816]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.71batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.08batches/s]
# Model 1 Training:   [Epoch 14, Loss: 0.000827, Acc: 0.8183, AUC: 0.5772]
# Model 1 Evaluation: [Epoch 14, Acc: 0.8179, AUC: 0.5828]
# Model 2 Training:   [Epoch 14, Loss: 0.000827, Acc: 0.8183, AUC: 0.5777]
# Model 2 Evaluation: [Epoch 14, Acc: 0.8179, AUC: 0.5832]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.80batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 80.09batches/s]
# Model 1 Training:   [Epoch 15, Loss: 0.000824, Acc: 0.8183, AUC: 0.5791]
# Model 1 Evaluation: [Epoch 15, Acc: 0.8179, AUC: 0.5859]
# Model 2 Training:   [Epoch 15, Loss: 0.000824, Acc: 0.8183, AUC: 0.5794]
# Model 2 Evaluation: [Epoch 15, Acc: 0.8179, AUC: 0.5859]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:37<00:00, 22.95batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.97batches/s]
# Model 1 Training:   [Epoch 16, Loss: 0.000819, Acc: 0.8183, AUC: 0.5793]
# Model 1 Evaluation: [Epoch 16, Acc: 0.8179, AUC: 0.5860]
# Model 2 Training:   [Epoch 16, Loss: 0.000819, Acc: 0.8183, AUC: 0.5796]
# Model 2 Evaluation: [Epoch 16, Acc: 0.8179, AUC: 0.5861]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.79batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 77.85batches/s]
# Model 1 Training:   [Epoch 17, Loss: 0.000820, Acc: 0.8183, AUC: 0.5800]
# Model 1 Evaluation: [Epoch 17, Acc: 0.8179, AUC: 0.5873]
# Model 2 Training:   [Epoch 17, Loss: 0.000820, Acc: 0.8183, AUC: 0.5802]
# Model 2 Evaluation: [Epoch 17, Acc: 0.8179, AUC: 0.5873]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.67batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.50batches/s]
# Model 1 Training:   [Epoch 18, Loss: 0.000815, Acc: 0.8183, AUC: 0.5823]
# Model 1 Evaluation: [Epoch 18, Acc: 0.8179, AUC: 0.5881]
# Model 2 Training:   [Epoch 18, Loss: 0.000815, Acc: 0.8183, AUC: 0.5826]
# Model 2 Evaluation: [Epoch 18, Acc: 0.8179, AUC: 0.5882]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:39<00:00, 22.57batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.03batches/s]
# Model 1 Training:   [Epoch 19, Loss: 0.000816, Acc: 0.8183, AUC: 0.5826]
# Model 1 Evaluation: [Epoch 19, Acc: 0.8179, AUC: 0.5884]
# Model 2 Training:   [Epoch 19, Loss: 0.000816, Acc: 0.8183, AUC: 0.5828]
# Model 2 Evaluation: [Epoch 19, Acc: 0.8179, AUC: 0.5891]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:39<00:00, 22.47batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.26batches/s]
# Model 1 Training:   [Epoch 20, Loss: 0.000830, Acc: 0.8183, AUC: 0.5781]
# Model 1 Evaluation: [Epoch 20, Acc: 0.8179, AUC: 0.5852]
# Model 2 Training:   [Epoch 20, Loss: 0.000830, Acc: 0.8183, AUC: 0.5796]
# Model 2 Evaluation: [Epoch 20, Acc: 0.8179, AUC: 0.5881]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:38<00:00, 22.74batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.39batches/s]
# Model 1 Training:   [Epoch 21, Loss: 0.000818, Acc: 0.8183, AUC: 0.5833]
# Model 1 Evaluation: [Epoch 21, Acc: 0.8179, AUC: 0.5920]
# Model 2 Training:   [Epoch 21, Loss: 0.000818, Acc: 0.8183, AUC: 0.5835]
# Model 2 Evaluation: [Epoch 21, Acc: 0.8179, AUC: 0.5913]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:39<00:00, 22.59batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.50batches/s]
# Model 1 Training:   [Epoch 22, Loss: 0.000822, Acc: 0.8183, AUC: 0.5812]
# Model 1 Evaluation: [Epoch 22, Acc: 0.8179, AUC: 0.5884]
# Model 2 Training:   [Epoch 22, Loss: 0.000822, Acc: 0.8183, AUC: 0.5824]
# Model 2 Evaluation: [Epoch 22, Acc: 0.8179, AUC: 0.5888]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:39<00:00, 22.52batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 77.12batches/s]
# Model 1 Training:   [Epoch 23, Loss: 0.000816, Acc: 0.8183, AUC: 0.5835]
# Model 1 Evaluation: [Epoch 23, Acc: 0.8179, AUC: 0.5902]
# Model 2 Training:   [Epoch 23, Loss: 0.000816, Acc: 0.8183, AUC: 0.5840]
# Model 2 Evaluation: [Epoch 23, Acc: 0.8179, AUC: 0.5898]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:40<00:00, 22.34batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.21batches/s]
# Model 1 Training:   [Epoch 24, Loss: 0.000813, Acc: 0.8183, AUC: 0.5852]
# Model 1 Evaluation: [Epoch 24, Acc: 0.8179, AUC: 0.5913]
# Model 2 Training:   [Epoch 24, Loss: 0.000813, Acc: 0.8183, AUC: 0.5853]
# Model 2 Evaluation: [Epoch 24, Acc: 0.8179, AUC: 0.5913]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:39<00:00, 22.46batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.30batches/s]
# Model 1 Training:   [Epoch 25, Loss: 0.000814, Acc: 0.8183, AUC: 0.5863]
# Model 1 Evaluation: [Epoch 25, Acc: 0.8179, AUC: 0.5934]
# Model 2 Training:   [Epoch 25, Loss: 0.000814, Acc: 0.8183, AUC: 0.5867]
# Model 2 Evaluation: [Epoch 25, Acc: 0.8179, AUC: 0.5935]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:40<00:00, 22.32batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.06batches/s]
# Model 1 Training:   [Epoch 26, Loss: 0.000812, Acc: 0.8183, AUC: 0.5868]
# Model 1 Evaluation: [Epoch 26, Acc: 0.8179, AUC: 0.5948]
# Model 2 Training:   [Epoch 26, Loss: 0.000812, Acc: 0.8183, AUC: 0.5874]
# Model 2 Evaluation: [Epoch 26, Acc: 0.8179, AUC: 0.5951]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:40<00:00, 22.39batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.17batches/s]
# Model 1 Training:   [Epoch 27, Loss: 0.000810, Acc: 0.8183, AUC: 0.5880]
# Model 1 Evaluation: [Epoch 27, Acc: 0.8179, AUC: 0.5955]
# Model 2 Training:   [Epoch 27, Loss: 0.000810, Acc: 0.8183, AUC: 0.5884]
# Model 2 Evaluation: [Epoch 27, Acc: 0.8179, AUC: 0.5959]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:40<00:00, 22.41batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.08batches/s]
# Model 1 Training:   [Epoch 28, Loss: 0.000808, Acc: 0.8183, AUC: 0.5886]
# Model 1 Evaluation: [Epoch 28, Acc: 0.8179, AUC: 0.5964]
# Model 2 Training:   [Epoch 28, Loss: 0.000808, Acc: 0.8183, AUC: 0.5889]
# Model 2 Evaluation: [Epoch 28, Acc: 0.8179, AUC: 0.5961]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:39<00:00, 22.48batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.36batches/s]
# Model 1 Training:   [Epoch 29, Loss: 0.000810, Acc: 0.8183, AUC: 0.5885]
# Model 1 Evaluation: [Epoch 29, Acc: 0.8179, AUC: 0.5952]
# Model 2 Training:   [Epoch 29, Loss: 0.000810, Acc: 0.8183, AUC: 0.5885]
# Model 2 Evaluation: [Epoch 29, Acc: 0.8179, AUC: 0.5956]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:40<00:00, 22.31batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 77.47batches/s]
# Model 1 Training:   [Epoch 30, Loss: 0.000809, Acc: 0.8183, AUC: 0.5892]
# Model 1 Evaluation: [Epoch 30, Acc: 0.8179, AUC: 0.5971]
# Model 2 Training:   [Epoch 30, Loss: 0.000809, Acc: 0.8183, AUC: 0.5895]
# Model 2 Evaluation: [Epoch 30, Acc: 0.8179, AUC: 0.5979]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:40<00:00, 22.41batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 78.18batches/s]
# Model 1 Training:   [Epoch 31, Loss: 0.000810, Acc: 0.8183, AUC: 0.5905]
# Model 1 Evaluation: [Epoch 31, Acc: 0.8179, AUC: 0.5975]
# Model 2 Training:   [Epoch 31, Loss: 0.000810, Acc: 0.8183, AUC: 0.5905]
# Model 2 Evaluation: [Epoch 31, Acc: 0.8179, AUC: 0.5974]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:39<00:00, 22.64batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 80.64batches/s]
# Model 1 Training:   [Epoch 32, Loss: 0.000809, Acc: 0.8183, AUC: 0.5908]
# Model 1 Evaluation: [Epoch 32, Acc: 0.8179, AUC: 0.5988]
# Model 2 Training:   [Epoch 32, Loss: 0.000809, Acc: 0.8183, AUC: 0.5908]
# Model 2 Evaluation: [Epoch 32, Acc: 0.8179, AUC: 0.5983]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:37<00:00, 23.06batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.97batches/s]
# Model 1 Training:   [Epoch 33, Loss: 0.000806, Acc: 0.8183, AUC: 0.5913]
# Model 1 Evaluation: [Epoch 33, Acc: 0.8179, AUC: 0.5983]
# Model 2 Training:   [Epoch 33, Loss: 0.000806, Acc: 0.8183, AUC: 0.5914]
# Model 2 Evaluation: [Epoch 33, Acc: 0.8179, AUC: 0.5983]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:37<00:00, 23.05batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 79.94batches/s]
# Model 1 Training:   [Epoch 34, Loss: 0.000806, Acc: 0.8183, AUC: 0.5911]
# Model 1 Evaluation: [Epoch 34, Acc: 0.8179, AUC: 0.5991]
# Model 2 Training:   [Epoch 34, Loss: 0.000806, Acc: 0.8183, AUC: 0.5912]
# Model 2 Evaluation: [Epoch 34, Acc: 0.8179, AUC: 0.5991]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:37<00:00, 23.01batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 80.22batches/s]
# Model 1 Training:   [Epoch 35, Loss: 0.000807, Acc: 0.8183, AUC: 0.5919]
# Model 1 Evaluation: [Epoch 35, Acc: 0.8179, AUC: 0.5999]
# Model 2 Training:   [Epoch 35, Loss: 0.000807, Acc: 0.8183, AUC: 0.5920]
# Model 2 Evaluation: [Epoch 35, Acc: 0.8179, AUC: 0.6003]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:35<00:00, 23.55batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.48batches/s]
# Model 1 Training:   [Epoch 36, Loss: 0.000805, Acc: 0.8183, AUC: 0.5925]
# Model 1 Evaluation: [Epoch 36, Acc: 0.8179, AUC: 0.6014]
# Model 2 Training:   [Epoch 36, Loss: 0.000805, Acc: 0.8183, AUC: 0.5926]
# Model 2 Evaluation: [Epoch 36, Acc: 0.8179, AUC: 0.6012]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 24.07batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.82batches/s]
# Model 1 Training:   [Epoch 37, Loss: 0.000804, Acc: 0.8183, AUC: 0.5933]
# Model 1 Evaluation: [Epoch 37, Acc: 0.8179, AUC: 0.6007]
# Model 2 Training:   [Epoch 37, Loss: 0.000804, Acc: 0.8183, AUC: 0.5931]
# Model 2 Evaluation: [Epoch 37, Acc: 0.8179, AUC: 0.6003]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 23.91batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.22batches/s]
# Model 1 Training:   [Epoch 38, Loss: 0.000807, Acc: 0.8183, AUC: 0.5932]
# Model 1 Evaluation: [Epoch 38, Acc: 0.8179, AUC: 0.6014]
# Model 2 Training:   [Epoch 38, Loss: 0.000807, Acc: 0.8183, AUC: 0.5930]
# Model 2 Evaluation: [Epoch 38, Acc: 0.8179, AUC: 0.6006]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.16batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.16batches/s]
# Model 1 Training:   [Epoch 39, Loss: 0.000805, Acc: 0.8183, AUC: 0.5932]
# Model 1 Evaluation: [Epoch 39, Acc: 0.8179, AUC: 0.6007]
# Model 2 Training:   [Epoch 39, Loss: 0.000805, Acc: 0.8183, AUC: 0.5931]
# Model 2 Evaluation: [Epoch 39, Acc: 0.8179, AUC: 0.6004]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.18batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.10batches/s]
# Model 1 Training:   [Epoch 40, Loss: 0.000805, Acc: 0.8183, AUC: 0.5936]
# Model 1 Evaluation: [Epoch 40, Acc: 0.8179, AUC: 0.6008]
# Model 2 Training:   [Epoch 40, Loss: 0.000805, Acc: 0.8183, AUC: 0.5935]
# Model 2 Evaluation: [Epoch 40, Acc: 0.8179, AUC: 0.6012]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 24.09batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.51batches/s]
# Model 1 Training:   [Epoch 41, Loss: 0.000803, Acc: 0.8183, AUC: 0.5942]
# Model 1 Evaluation: [Epoch 41, Acc: 0.8179, AUC: 0.6019]
# Model 2 Training:   [Epoch 41, Loss: 0.000803, Acc: 0.8183, AUC: 0.5945]
# Model 2 Evaluation: [Epoch 41, Acc: 0.8179, AUC: 0.6025]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.12batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.08batches/s]
# Model 1 Training:   [Epoch 42, Loss: 0.000805, Acc: 0.8183, AUC: 0.5949]
# Model 1 Evaluation: [Epoch 42, Acc: 0.8179, AUC: 0.6018]
# Model 2 Training:   [Epoch 42, Loss: 0.000805, Acc: 0.8183, AUC: 0.5951]
# Model 2 Evaluation: [Epoch 42, Acc: 0.8179, AUC: 0.6022]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 24.01batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.53batches/s]
# Model 1 Training:   [Epoch 43, Loss: 0.000805, Acc: 0.8183, AUC: 0.5952]
# Model 1 Evaluation: [Epoch 43, Acc: 0.8179, AUC: 0.6031]
# Model 2 Training:   [Epoch 43, Loss: 0.000805, Acc: 0.8183, AUC: 0.5952]
# Model 2 Evaluation: [Epoch 43, Acc: 0.8179, AUC: 0.6036]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.18batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.35batches/s]
# Model 1 Training:   [Epoch 44, Loss: 0.000806, Acc: 0.8183, AUC: 0.5945]
# Model 1 Evaluation: [Epoch 44, Acc: 0.8179, AUC: 0.6021]
# Model 2 Training:   [Epoch 44, Loss: 0.000806, Acc: 0.8183, AUC: 0.5945]
# Model 2 Evaluation: [Epoch 44, Acc: 0.8179, AUC: 0.6023]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.17batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.86batches/s]
# Model 1 Training:   [Epoch 45, Loss: 0.000803, Acc: 0.8183, AUC: 0.5956]
# Model 1 Evaluation: [Epoch 45, Acc: 0.8179, AUC: 0.6022]
# Model 2 Training:   [Epoch 45, Loss: 0.000803, Acc: 0.8183, AUC: 0.5957]
# Model 2 Evaluation: [Epoch 45, Acc: 0.8179, AUC: 0.6023]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.25batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.60batches/s]
# Model 1 Training:   [Epoch 46, Loss: 0.000801, Acc: 0.8183, AUC: 0.5960]
# Model 1 Evaluation: [Epoch 46, Acc: 0.8179, AUC: 0.6030]
# Model 2 Training:   [Epoch 46, Loss: 0.000801, Acc: 0.8183, AUC: 0.5964]
# Model 2 Evaluation: [Epoch 46, Acc: 0.8179, AUC: 0.6035]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.19batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.64batches/s]
# Model 1 Training:   [Epoch 47, Loss: 0.000806, Acc: 0.8183, AUC: 0.5959]
# Model 1 Evaluation: [Epoch 47, Acc: 0.8179, AUC: 0.6035]
# Model 2 Training:   [Epoch 47, Loss: 0.000806, Acc: 0.8183, AUC: 0.5961]
# Model 2 Evaluation: [Epoch 47, Acc: 0.8179, AUC: 0.6031]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.20batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.63batches/s]
# Model 1 Training:   [Epoch 48, Loss: 0.000802, Acc: 0.8183, AUC: 0.5960]
# Model 1 Evaluation: [Epoch 48, Acc: 0.8179, AUC: 0.6038]
# Model 2 Training:   [Epoch 48, Loss: 0.000802, Acc: 0.8183, AUC: 0.5960]
# Model 2 Evaluation: [Epoch 48, Acc: 0.8179, AUC: 0.6037]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 24.02batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.51batches/s]
# Model 1 Training:   [Epoch 49, Loss: 0.000801, Acc: 0.8183, AUC: 0.5962]
# Model 1 Evaluation: [Epoch 49, Acc: 0.8179, AUC: 0.6020]
# Model 2 Training:   [Epoch 49, Loss: 0.000801, Acc: 0.8183, AUC: 0.5963]
# Model 2 Evaluation: [Epoch 49, Acc: 0.8179, AUC: 0.6012]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 23.90batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.58batches/s]
# Model 1 Training:   [Epoch 50, Loss: 0.000801, Acc: 0.8183, AUC: 0.5957]
# Model 1 Evaluation: [Epoch 50, Acc: 0.8179, AUC: 0.6049]
# Model 2 Training:   [Epoch 50, Loss: 0.000801, Acc: 0.8183, AUC: 0.5960]
# Model 2 Evaluation: [Epoch 50, Acc: 0.8179, AUC: 0.6050]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.19batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 82.88batches/s]
# Model 1 Training:   [Epoch 51, Loss: 0.000799, Acc: 0.8183, AUC: 0.5977]
# Model 1 Evaluation: [Epoch 51, Acc: 0.8179, AUC: 0.6051]
# Model 2 Training:   [Epoch 51, Loss: 0.000799, Acc: 0.8183, AUC: 0.5977]
# Model 2 Evaluation: [Epoch 51, Acc: 0.8179, AUC: 0.6043]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 24.06batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.51batches/s]
# Model 1 Training:   [Epoch 52, Loss: 0.000799, Acc: 0.8183, AUC: 0.5969]
# Model 1 Evaluation: [Epoch 52, Acc: 0.8179, AUC: 0.6041]
# Model 2 Training:   [Epoch 52, Loss: 0.000799, Acc: 0.8183, AUC: 0.5972]
# Model 2 Evaluation: [Epoch 52, Acc: 0.8179, AUC: 0.6049]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 24.06batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.39batches/s]
# Model 1 Training:   [Epoch 53, Loss: 0.000800, Acc: 0.8183, AUC: 0.5972]
# Model 1 Evaluation: [Epoch 53, Acc: 0.8179, AUC: 0.6042]
# Model 2 Training:   [Epoch 53, Loss: 0.000800, Acc: 0.8183, AUC: 0.5973]
# Model 2 Evaluation: [Epoch 53, Acc: 0.8179, AUC: 0.6036]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.16batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.38batches/s]
# Model 1 Training:   [Epoch 54, Loss: 0.000800, Acc: 0.8183, AUC: 0.5974]
# Model 1 Evaluation: [Epoch 54, Acc: 0.8179, AUC: 0.6049]
# Model 2 Training:   [Epoch 54, Loss: 0.000800, Acc: 0.8183, AUC: 0.5973]
# Model 2 Evaluation: [Epoch 54, Acc: 0.8179, AUC: 0.6041]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 24.10batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.36batches/s]
# Model 1 Training:   [Epoch 55, Loss: 0.000797, Acc: 0.8183, AUC: 0.5988]
# Model 1 Evaluation: [Epoch 55, Acc: 0.8179, AUC: 0.6057]
# Model 2 Training:   [Epoch 55, Loss: 0.000797, Acc: 0.8183, AUC: 0.5986]
# Model 2 Evaluation: [Epoch 55, Acc: 0.8179, AUC: 0.6054]
# saved model1
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.14batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.66batches/s]
# Model 1 Training:   [Epoch 56, Loss: 0.000800, Acc: 0.8183, AUC: 0.5984]
# Model 1 Evaluation: [Epoch 56, Acc: 0.8179, AUC: 0.6031]
# Model 2 Training:   [Epoch 56, Loss: 0.000800, Acc: 0.8183, AUC: 0.5983]
# Model 2 Evaluation: [Epoch 56, Acc: 0.8179, AUC: 0.6033]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 23.99batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.05batches/s]
# Model 1 Training:   [Epoch 57, Loss: 0.000801, Acc: 0.8183, AUC: 0.5983]
# Model 1 Evaluation: [Epoch 57, Acc: 0.8179, AUC: 0.6058]
# Model 2 Training:   [Epoch 57, Loss: 0.000801, Acc: 0.8183, AUC: 0.5985]
# Model 2 Evaluation: [Epoch 57, Acc: 0.8179, AUC: 0.6066]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:32<00:00, 24.17batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.35batches/s]
# Model 1 Training:   [Epoch 58, Loss: 0.000798, Acc: 0.8183, AUC: 0.5991]
# Model 1 Evaluation: [Epoch 58, Acc: 0.8179, AUC: 0.6047]
# Model 2 Training:   [Epoch 58, Loss: 0.000798, Acc: 0.8183, AUC: 0.5998]
# Model 2 Evaluation: [Epoch 58, Acc: 0.8179, AUC: 0.6055]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 24.09batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.50batches/s]
# Model 1 Training:   [Epoch 59, Loss: 0.000800, Acc: 0.8183, AUC: 0.5994]
# Model 1 Evaluation: [Epoch 59, Acc: 0.8179, AUC: 0.6066]
# Model 2 Training:   [Epoch 59, Loss: 0.000800, Acc: 0.8183, AUC: 0.5999]
# Model 2 Evaluation: [Epoch 59, Acc: 0.8179, AUC: 0.6067]
# saved model2
# Train: 100%|████████████████████████████████████████████████████| 2243/2243 [01:33<00:00, 24.01batches/s]
# Eval: 100%|███████████████████████████████████████████████████████| 281/281 [00:03<00:00, 83.51batches/s]
# Model 1 Training:   [Epoch 60, Loss: 0.000796, Acc: 0.8183, AUC: 0.5989]
# Model 1 Evaluation: [Epoch 60, Acc: 0.8179, AUC: 0.6069]
# Model 2 Training:   [Epoch 60, Loss: 0.000796, Acc: 0.8183, AUC: 0.5998]
# Model 2 Evaluation: [Epoch 60, Acc: 0.8179, AUC: 0.6075]
# saved model2
# Finished Training.
# Training took 101.11342788139979 minutes.

# %%
test_path = '../../data/n_test.csv'
test_seqs, test_lbls = read_data(test_path)

test_data = CleavageDataset(test_seqs, test_lbls)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, collate_fn=eval_wrapper, pin_memory=True, num_workers=10)

# load best model, evaluate on test set
best_model = sorted(
    [f for f in os.listdir("../../params/n_term/cnnAttention_jocor/") if f.endswith(".pt")],
    reverse=True,
)[0]
print("Loaded model: ", best_model)
model1.load_state_dict(torch.load('../../params/n_term/cnnAttention_jocor/' + best_model))
model1.eval()
with torch.no_grad():
    test_acc, test_auc = test(model1, test_loader)
print(
    f"Test Set Performance: Acc: {test_acc:.4f}, AUC: {test_auc:.4f}"
)
print(
    f"Total model params: {total_model_params(model1)}, trainable model params: {trainable_model_params(model1)}"
)
# Out:
# Loaded model:  auc0.6075_epoch60.pt
# Eval: 100%|██████████████████████████████████████████████████████| 281/281 [00:01<00:00, 151.76batches/s]
# Test Set Performance: Acc: 0.8188, AUC: 0.6081
# Total model params: 15237057, trainable model params: 15237057
